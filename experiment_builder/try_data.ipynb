# %%
from pathlib import Path
import sys
import os

PROJECT_ROOT = Path.cwd().parent

import csv
import pandas as pd

from src.data_paths import (
    EXPERIMENT_TEXT_COMPLETED_PATH,

    DATA_DIR,
    EXPERIMENT_DIR,

)

# %%
msg = pd.read_csv(
    EXPERIMENT_DIR / "fake result" / "msg.tsv",
    encoding="utf-8",
    sep="\t",
    quoting=csv.QUOTE_NONE,
    engine="python"
)

# %%
fix = pd.read_csv(
    EXPERIMENT_DIR / "fake result" / "rep.tsv",
    encoding="utf-8",
    sep="\t",
    quoting=csv.QUOTE_NONE,
    engine="python"
)

# %%
ia = pd.read_csv(
    EXPERIMENT_DIR / "fake result" / "ia.tsv",
    encoding="utf-8",
    sep="\t",
    quoting=csv.QUOTE_NONE,
    engine="python"
)

# %%
fix
# Out:
#      RECORDING_SESSION_LABEL  TRIAL_INDEX  CURRENT_FIX_ADJUSTED  \
# 0                      Test2            1                 False
# 1                      Test2            1                 False
# 2                      Test2            1                 False
# 3                      Test2            1                 False
# 4                      Test2            1                 False
# ...                      ...          ...                   ...
# 2715                   Test2           23                 False
# 2716                   Test2           23                 False
# 2717                   Test2           23                 False
# 2718                   Test2           23                 False
# 2719                   Test2           23                 False
#
#      CURRENT_FIX_BLINK_AROUND CURRENT_FIX_BUTTON_0_PRESS  \
# 0                        NONE                          .
# 1                        NONE                          .
# 2                        NONE                          .
# 3                        NONE                          .
# 4                        NONE                          .
# ...                       ...                        ...
# 2715                     NONE                          .
# 2716                     NONE                          .
# 2717                     NONE                          .
# 2718                     NONE                          .
# 2719                     NONE                          .
#
#      CURRENT_FIX_BUTTON_1_PRESS CURRENT_FIX_BUTTON_2_PRESS  \
# 0                             .                          .
# 1                             .                          .
# 2                             .                          .
# 3                             .                          .
# 4                             .                          .
# ...                         ...                        ...
# 2715                          .                          .
# 2716                          .                          .
# 2717                          .                          .
# 2718                          .                          .
# 2719                          .                          .
#
#      CURRENT_FIX_BUTTON_3_PRESS CURRENT_FIX_BUTTON_4_PRESS  \
# 0                             .                          .
# 1                             .                          .
# 2                             .                          .
# 3                             .                          .
# 4                             .                          .
# ...                         ...                        ...
# 2715                          .                          .
# 2716                          .                          .
# 2717                          .                          .
# 2718                          .                          .
# 2719                          .                          .
#
#      CURRENT_FIX_BUTTON_5_PRESS  ... is_experimental is_practice list_num  \
# 0                             .  ...               0        True        0
# 1                             .  ...               0        True        0
# 2                             .  ...               0        True        0
# 3                             .  ...               0        True        0
# 4                             .  ...               0        True        0
# ...                         ...  ...             ...         ...      ...
# 2715                          .  ...               1       False        0
# 2716                          .  ...               1       False        0
# 2717                          .  ...               1       False        0
# 2718                          .  ...               1       False        0
# 2719                          .  ...               1       False        0
#
#       list_version  onestopqa_question_id paragraph_id  \
# 0               1a                      0            1
# 1               1a                      0            1
# 2               1a                      0            1
# 3               1a                      0            1
# 4               1a                      0            1
# ...            ...                    ...          ...
# 2715            1a                      0            2
# 2716            1a                      0            2
# 2717            1a                      0            2
# 2718            1a                      0            2
# 2719            1a                      0            2
#
#                                                question question_list_version  \
# 0     According to Malik Falkenmark's report, what w...                     0
# 1     According to Malik Falkenmark's report, what w...                     0
# 2     According to Malik Falkenmark's report, what w...                     0
# 3     According to Malik Falkenmark's report, what w...                     0
# 4     According to Malik Falkenmark's report, what w...                     0
# ...                                                 ...                   ...
# 2715                 What does Pullman find outrageous?                     0
# 2716                 What does Pullman find outrageous?                     0
# 2717                 What does Pullman find outrageous?                     0
# 2718                 What does Pullman find outrageous?                     0
# 2719                 What does Pullman find outrageous?                     0
#
#                                      rephrased_answer_a  \
# 0     There won't be enough water to grow food for a...
# 1     There won't be enough water to grow food for a...
# 2     There won't be enough water to grow food for a...
# 3     There won't be enough water to grow food for a...
# 4     There won't be enough water to grow food for a...
# ...                                                 ...
# 2715  That people can steal artists' work without co...
# 2716  That people can steal artists' work without co...
# 2717  That people can steal artists' work without co...
# 2718  That people can steal artists' work without co...
# 2719  That people can steal artists' work without co...
#
#      selected_onestopqa_question_id
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 2715                              0
# 2716                              0
# 2717                              0
# 2718                              0
# 2719                              0
#
# [2720 rows x 314 columns]
