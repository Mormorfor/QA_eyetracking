# %%
import warnings
warnings.filterwarnings("ignore", message=".*DataFrame.applymap.*", category=FutureWarning)

import mixed_text_answer_effects as M
from importlib import reload
reload(M)

import constants as C

# %%
merged_h, merged_g = M.load_merged_data(
    hunters_path="output_data/merged_hunters.csv",
    gatherers_path="output_data/merged_gatherers.csv",
)
# Out:
# Loading hunters data from: output_data/merged_hunters.csv
# Loading gatherers data from: output_data/merged_gatherers.csv

# %%
models_h_sep = M.fit_no_slopes_for_all_answers(merged_h, M.TERMS, separated=True)
models_g_sep = M.fit_no_slopes_for_all_answers(merged_g, M.TERMS, separated=True)

M.plot_fixed_effects(M.TERMS, models_h_sep, h_or_g="hunters", separated_label="answ_separated")
M.plot_fixed_effects(M.TERMS, models_g_sep, h_or_g="gatherers", separated_label="answ_separated")
# Out:
# Fitting model (separated by answer selected) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 8449	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -56020.931 	 AIC: 112055.862
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  13724.583  117.152
# participant_id  (Intercept)   2869.283   53.566
# Residual                     27618.130  166.187
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# Model failed to converge with max|grad| = 0.00295769 (tol = 0.002, component 1)
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 744	 Groups: {'text_id_with_q': 391.0, 'participant_id': 175.0}
#
# Log-likelihood: -5297.364 	 AIC: 10608.729
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  37471.833  193.576
# participant_id  (Intercept)   8613.242   92.808
# Residual                     54904.689  234.317
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 374	 Groups: {'text_id_with_q': 246.0, 'participant_id': 146.0}
#
# Log-likelihood: -2627.976 	 AIC: 5269.952
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  13019.782  114.104
# participant_id  (Intercept)   1635.825   40.445
# Residual                     64632.315  254.229
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 152	 Groups: {'text_id_with_q': 108.0, 'participant_id': 91.0}
#
# Log-likelihood: -1061.858 	 AIC: 2137.716
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  35528.710  188.491
# participant_id  (Intercept)    806.300   28.395
# Residual                     42249.463  205.547
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 7890	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -52590.429 	 AIC: 105194.858
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  16687.369  129.180
# participant_id  (Intercept)   3209.428   56.652
# Residual                     28922.188  170.065
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 1000	 Groups: {'text_id_with_q': 459.0, 'participant_id': 179.0}
#
# Log-likelihood: -7299.636 	 AIC: 14613.272
#
# Random effects:
#
#                        Name         Var      Std
# text_id_with_q  (Intercept)   26399.377  162.479
# participant_id  (Intercept)    6573.148   81.075
# Residual                     104620.759  323.451
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 568	 Groups: {'text_id_with_q': 331.0, 'participant_id': 169.0}
#
# Log-likelihood: -4023.737 	 AIC: 8061.474
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  28239.388  168.046
# participant_id  (Intercept)  11303.881  106.320
# Residual                     53538.099  231.383
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 259	 Groups: {'text_id_with_q': 175.0, 'participant_id': 130.0}
#
# Log-likelihood: -1821.118 	 AIC: 3656.236
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  34517.494  185.789
# participant_id  (Intercept)   7858.575   88.649
# Residual                     41267.470  203.144
#
# No random effect correlations specified
#
# Fixed effects:

# %%
models_h_all = M.fit_no_slopes_for_all_answers(merged_h, M.TERMS, separated=False)
models_g_all = M.fit_no_slopes_for_all_answers(merged_g, M.TERMS, separated=False)

M.plot_fixed_effects(M.TERMS, models_h_all, h_or_g="hunters", separated_label="all_answ")
M.plot_fixed_effects(M.TERMS, models_g_all, h_or_g="gatherers", separated_label="all_answ")
# Out:
# Fitting model (all) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -64588.586 	 AIC: 129191.173
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  12252.236  110.690
# participant_id  (Intercept)   2848.325   53.370
# Residual                     29241.383  171.001
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -63206.026 	 AIC: 126426.052
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   5594.404   74.796
# participant_id  (Intercept)   1186.426   34.445
# Residual                     23120.036  152.053
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -62019.597 	 AIC: 124053.194
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   4166.495   64.548
# participant_id  (Intercept)    882.701   29.710
# Residual                     18182.424  134.842
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -60874.716 	 AIC: 121763.431
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   4315.526   65.693
# participant_id  (Intercept)    738.371   27.173
# Residual                     14042.848  118.503
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -65289.570 	 AIC: 130593.141
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  14185.909  119.105
# participant_id  (Intercept)   2989.077   54.672
# Residual                     33938.573  184.224
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -64697.445 	 AIC: 129408.891
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   9018.925   94.968
# participant_id  (Intercept)   1984.158   44.544
# Residual                     31027.605  176.147
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -62554.213 	 AIC: 125122.427
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   5969.526   77.263
# participant_id  (Intercept)   1738.049   41.690
# Residual                     19794.633  140.693
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -61827.341 	 AIC: 123668.682
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   5382.082   73.363
# participant_id  (Intercept)   1297.979   36.027
# Residual                     17011.410  130.428
#
# No random effect correlations specified
#
# Fixed effects:

# %%
models_h_sloped = {}
models_g_sloped = {}

sep = True
corr = True

for label in C.ANSWER_LABELS:
    m_h = M.build_model_with_slopes(
        merged_h,
        answer_label=label,
        terms=M.TERMS,
        separated=sep,
        correlated_slopes=corr,
    )
    models_h_sloped[label] = m_h
    M.plot_participant_effects(
        m_h, f"Answer {label}",
        M.TERMS, h_or_g="hunters",
        separated=sep,
        correlated_slopes=corr
        )

    m_g = M.build_model_with_slopes(
        merged_g,
        answer_label=label,
        terms=M.TERMS,
        separated=sep,
        correlated_slopes=corr,
    )
    models_g_sloped[label] = m_g
    M.plot_participant_effects(
        m_g, f"Answer {label}",
        M.TERMS, h_or_g="gatherers",
        separated=sep,
        correlated_slopes=corr
        )
# Out:
# Fitting random-slope model for answer A: answer_A ~ critical + distractor + outside + (1 + critical + distractor + outside | participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1+critical+distractor+outside|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 8449	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -56119.606 	 AIC: 112271.212
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  32410.679  180.030
# participant_id  (Intercept)      0.017    0.131
# participant_id     critical      0.041    0.202
# participant_id   distractor      0.018    0.135
# participant_id      outside      0.045    0.212
# Residual                     25547.733  159.837
#
#                         IV1         IV2   Corr
# participant_id  (Intercept)    critical -0.111
# participant_id  (Intercept)  distractor  0.281
# participant_id  (Intercept)     outside -0.925
# participant_id     critical  distractor -0.018
# participant_id     critical     outside  0.080
# participant_id   distractor     outside -0.624
#
# Fixed effects:
#
#
# === Answer A: fixed effects (separated, correlated) ===
# critical     β=0.081 ± 0.059  p=0.007263 **
# distractor   β=0.041 ± 0.048  p=0.09336 .
# outside      β=0.158 ± 0.077  p=8.142e-05 ***
# Saved fixed-effects table to: output_data/slopes\separated__correlated\fixed_effects_Answer A_hunters.csv
# Saved intercept plot to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_intercept_hunters.png
# Saved slope plot for critical to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_critical_hunters.png
# Saved slope plot for distractor to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_distractor_hunters.png
# Saved slope plot for outside to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_outside_hunters.png
# Fitting random-slope model for answer A: answer_A ~ critical + distractor + outside + (1 + critical + distractor + outside | participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1+critical+distractor+outside|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 7890	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -52718.468 	 AIC: 105468.936
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  42536.771  206.244
# participant_id  (Intercept)      1.076    1.037
# participant_id     critical      0.094    0.307
# participant_id   distractor      0.009    0.096
# participant_id      outside      0.050    0.225
# Residual                     26327.141  162.256
#
#                         IV1         IV2   Corr
# participant_id  (Intercept)    critical -0.533
# participant_id  (Intercept)  distractor -0.852
# participant_id  (Intercept)     outside  0.381
# participant_id     critical  distractor  0.021
# participant_id     critical     outside -0.491
# participant_id   distractor     outside -0.219
#
# Fixed effects:
#
#
# === Answer A: fixed effects (separated, correlated) ===
# critical     β=0.102 ± 0.075  p=0.008039 **
# distractor   β=0.046 ± 0.040  p=0.02502 *
# outside      β=0.165 ± 0.075  p=2.912e-05 ***
# Saved fixed-effects table to: output_data/slopes\separated__correlated\fixed_effects_Answer A_gatherers.csv
# Saved intercept plot to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_intercept_gatherers.png
# Saved slope plot for critical to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_critical_gatherers.png
# Saved slope plot for distractor to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_distractor_gatherers.png
# Saved slope plot for outside to: plots/texts_to_answers/participant_effects\separated__correlated\Answer A_outside_gatherers.png
# Fitting random-slope model for answer B: answer_B ~ critical + distractor + outside + (1 + critical + distractor + outside | participant_id) + (1 | text_id_with_q)
# [1] "Model failed to converge with max|grad| = 47.915 (tol = 0.002, component 1)"
# [2] " \n"
#
# [1] "Model is nearly unidentifiable: very large eigenvalue\n - Rescale variables?"
# [2] " \n"
#
# [1] "Model is nearly unidentifiable: large eigenvalue ratio\n - Rescale variables?"
# [2] " \n"
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1+critical+distractor+outside|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 744	 Groups: {'text_id_with_q': 391.0, 'participant_id': 175.0}
#
# Log-likelihood: -5302.288 	 AIC: 10636.575
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  88079.942  296.783
# participant_id  (Intercept)  31319.505  176.973
# participant_id     critical      0.529    0.727
# participant_id   distractor      1.083    1.041
# participant_id      outside      2.081    1.443
# Residual                     20925.885  144.658
#
#                         IV1         IV2   Corr
# participant_id  (Intercept)    critical -0.723
# participant_id  (Intercept)  distractor  0.259
# participant_id  (Intercept)     outside -0.436
# participant_id     critical  distractor -0.813
# participant_id     critical     outside  0.741
# participant_id   distractor     outside -0.883
#
# Fixed effects:
#
#
# === Answer B: fixed effects (separated, correlated) ===
# critical     β=0.276 ± 0.247  p=0.03144 *
# distractor   β=-0.191 ± 0.273  p=0.175
# outside      β=0.329 ± 0.420  p=0.1287
# Saved fixed-effects table to: output_data/slopes\separated__correlated\fixed_effects_Answer B_hunters.csv
# Saved intercept plot to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_intercept_hunters.png
# Saved slope plot for critical to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_critical_hunters.png
# Saved slope plot for distractor to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_distractor_hunters.png
# Saved slope plot for outside to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_outside_hunters.png
# Fitting random-slope model for answer B: answer_B ~ critical + distractor + outside + (1 + critical + distractor + outside | participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1+critical+distractor+outside|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 1000	 Groups: {'text_id_with_q': 459.0, 'participant_id': 179.0}
#
# Log-likelihood: -7297.025 	 AIC: 14626.050
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  22913.801  151.373
# participant_id  (Intercept)  98790.789  314.310
# participant_id     critical      0.309    0.556
# participant_id   distractor      0.062    0.249
# participant_id      outside      1.462    1.209
# Residual                     92827.694  304.676
#
#                         IV1         IV2   Corr
# participant_id  (Intercept)    critical  0.663
# participant_id  (Intercept)  distractor -0.403
# participant_id  (Intercept)     outside -0.987
# participant_id     critical  distractor -0.952
# participant_id     critical     outside -0.773
# participant_id   distractor     outside  0.543
#
# Fixed effects:
#
#
# === Answer B: fixed effects (separated, correlated) ===
# critical     β=0.496 ± 0.255  p=0.0002558 ***
# distractor   β=0.111 ± 0.195  p=0.2667
# outside      β=-0.110 ± 0.363  p=0.554
# Saved fixed-effects table to: output_data/slopes\separated__correlated\fixed_effects_Answer B_gatherers.csv
# Saved intercept plot to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_intercept_gatherers.png
# Saved slope plot for critical to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_critical_gatherers.png
# Saved slope plot for distractor to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_distractor_gatherers.png
# Saved slope plot for outside to: plots/texts_to_answers/participant_effects\separated__correlated\Answer B_outside_gatherers.png
# Fitting random-slope model for answer C: answer_C ~ critical + distractor + outside + (1 + critical + distractor + outside | participant_id) + (1 | text_id_with_q)
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[26], line 8
#       5 corr = True
#       7 for label in C.ANSWER_LABELS:
# ----> 8     m_h = M.build_model_with_slopes(
#       9         merged_h,
#      10         answer_label=label,
#      11         terms=M.TERMS,
#      12         separated=sep,
#      13         correlated_slopes=corr,
#      14     )
#      15     models_h_sloped[label] = m_h
#      16     M.plot_participant_effects(
#      17         m_h, f"Answer {label}",
#      18         M.TERMS, h_or_g="hunters",
#      19         separated=sep,
#      20         correlated_slopes=corr
#      21         )
#
# File ~\PycharmProjects\QA_eyetracking\mixed_text_answer_effects.py:401, in build_model_with_slopes(df, answer_label, terms, separated, correlated_slopes)
#     399 print(f"Fitting random-slope model for answer {answer_label}: {formula}")
#     400 m = Lmer(formula, data=df)
# --> 401 m.fit()
#     402 return m
#
# File ~\miniconda3\envs\QA_eyetracking_env\lib\site-packages\pymer4\models\Lmer.py:424, in Lmer.fit(self, conf_int, n_boot, factors, permute, ordered, verbose, REML, rank, rank_group, rank_exclude_cols, no_warnings, control, old_optimizer, **kwargs)
#     422     lmer = importr("lmerTest")
#     423     lmc = robjects.r(f"lmerControl({control})")
# --> 424     self.model_obj = lmer.lmer(
#     425         self.formula, data=data, REML=REML, control=lmc, contrasts=contrasts
#     426     )
#     427 else:
#     428     if verbose:
#
# File ~\miniconda3\envs\QA_eyetracking_env\lib\site-packages\rpy2\robjects\functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     206         v = kwargs.pop(k)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File ~\miniconda3\envs\QA_eyetracking_env\lib\site-packages\rpy2\robjects\functions.py:131, in Function.__call__(self, *args, **kwargs)
#     129     else:
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#     133 return res
#
# File ~\miniconda3\envs\QA_eyetracking_env\lib\site-packages\rpy2\rinterface_lib\conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File ~\miniconda3\envs\QA_eyetracking_env\lib\site-packages\rpy2\rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     810     res = rmemory.protect(
#     811         openrlib.rlib.R_tryEval(
#     812             call_r,
#     813             call_context.__sexp__._cdata,
#     814             error_occured)
#     815     )
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error: number of observations (=373) <= number of random effects (=584) for term (1 + critical + distractor + outside | participant_id); the random-effects parameters and the residual variance (or scale parameter) are probably unidentifiable
