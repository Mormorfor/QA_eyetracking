# %%
import pandas as pd
import numpy as np

# %%
ia_Q_path = "full/ia_Q.csv"
ia_A_path = "full/ia_A.csv"
ia_QA_path = "full/ia_QA.csv"

# %%
#df_Q = pd.read_csv(ia_Q_path)
df_A = pd.read_csv(ia_A_path)
#df_QA = pd.read_csv(ia_QA_path)

# %%
df_A_filtered = df_A[(df_A['repeated_reading_trial'] == False) & ((df_A['practice_trial'] == False))]

df_A_hunters = df_A_filtered[df_A_filtered['question_preview'] == True]
df_A_gatherers = df_A_filtered[df_A_filtered['question_preview'] == False]

# %%
def create_area_label(df):
    for col in ['question', 'answer_1', 'answer_2', 'answer_3', 'answer_4']:
        df[col] = df[col].fillna('').astype(str)

    df['question_tokens'] = df['question'].str.split()
    df['a_tokens'] = df['answer_1'].str.split()
    df['b_tokens'] = df['answer_2'].str.split()
    df['c_tokens'] = df['answer_3'].str.split()
    df['d_tokens'] = df['answer_4'].str.split()

    df['question_len'] = df['question_tokens'].apply(len)
    df['a_len'] = df['a_tokens'].apply(len)
    df['b_len'] = df['b_tokens'].apply(len)
    df['c_len'] = df['c_tokens'].apply(len)
    df['d_len'] = df['d_tokens'].apply(len)

    def assign_area(group):
        q_len = group['question_len'].iloc[0]
        a_len = group['a_len'].iloc[0]
        b_len = group['b_len'].iloc[0]
        c_len = group['c_len'].iloc[0]
        d_len = group['d_len'].iloc[0]

        q_end = q_len - 1
        a_end = q_len + a_len - 1
        b_end = q_len + a_len + b_len - 1
        c_end = q_len + a_len + b_len + c_len - 1

        index_id = group['IA_ID'] - 1

        conditions = [
            (index_id <= q_end),
            (index_id > q_end) & (index_id <= a_end),
            (index_id > a_end) & (index_id <= b_end),
            (index_id > b_end) & (index_id <= c_end),
            (index_id > c_end)
        ]

        choices = ['question', 'answer_1', 'answer_2', 'answer_3', 'answer_4']
        group['area_label'] = np.select(conditions, choices, default='unknown')
        return group

    df_area_split = df.set_index(['TRIAL_INDEX', 'participant_id']).groupby(['TRIAL_INDEX', 'participant_id'], group_keys=False).apply(assign_area)
    return df_area_split

# %%
def create_correct_answer(df):
    df = df.copy()
    df['is_correct'] = (df['selected_answer_position'] == df['correct_answer_position']).astype(int)
    return df

# %%
def create_mean_area_dwell_time(df):
    return df.groupby(['TRIAL_INDEX', 'participant_id','area_label'], as_index=False).agg(mean_dwell_time=("IA_DWELL_TIME", "mean"))

# %%
def create_mean_area_fixation_count(df):
    return df.groupby(['TRIAL_INDEX', 'participant_id','area_label'], as_index=False).agg(mean_fixations_count=("IA_FIXATION_COUNT", "mean"))

# %%
def create_mean_first_fixation_duration(df):
    df['IA_FIRST_FIXATION_DURATION_INT'] = df["IA_FIRST_FIXATION_DURATION"].replace('.', 0).astype(int)
    return df.groupby(['TRIAL_INDEX', 'participant_id','area_label'], as_index=False).agg(mean_first_fixation_duration=("IA_FIRST_FIXATION_DURATION_INT", "mean"))

# %%
def create_skip_rate(df):
    return df.groupby(['TRIAL_INDEX', 'participant_id','area_label'], as_index=False).agg(skip_rate=("IA_SKIP", "mean"))

# %%
def create_dwell_proportions(df):
    aggregated_df = (
        df.groupby(['participant_id', 'TRIAL_ID', 'area_label'], as_index=False)
        .agg({'IA_DWELL_TIME': 'sum'})
        .rename(columns={'IA_DWELL_TIME': 'total_area_dwell_time'})
    )

    # Step 2: Calculate total dwell time per participant and trial
    aggregated_df['total_dwell_time'] = aggregated_df.groupby(['participant_id', 'TRIAL_ID'])['total_area_dwell_time'].transform('sum')

    # Step 3: Calculate the proportion of time spent in each area
    aggregated_df['area_dwell_proportion'] = aggregated_df['total_area_dwell_time'] / aggregated_df['total_dwell_time']

    return aggregated_df

# %%
df_base_features_h = create_correct_answer(df_A_hunters)
df_base_features_h = create_area_label(df_base_features_h).reset_index()

df_base_features_g = create_correct_answer(df_A_gatherers)
df_base_features_g = create_area_label(df_base_features_g).reset_index()

# %%
df_base_features_h
# Out:
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 4       l42_2070        RIGHT       Right
# 1                 4       l42_2070        RIGHT       Right
# 2                 4       l42_2070        RIGHT       Right
# 3                 4       l42_2070        RIGHT       Right
# 4                 4       l42_2070        RIGHT       Right
# ...             ...            ...          ...         ...
# 380345           59         l10_39         LEFT        Left
# 380346           59         l10_39         LEFT        Left
# 380347           59         l10_39         LEFT        Left
# 380348           59         l10_39         LEFT        Left
# 380349           59         l10_39         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10165.0                         .        261
# 1       RECORDING_SESSION   6099.0                   1078.00        261
# 2       RECORDING_SESSION  14231.0                         .        261
# 3       RECORDING_SESSION  28569.0                         .        261
# 4       RECORDING_SESSION   4180.0                   1139.00        492
# ...                   ...      ...                       ...        ...
# 380345  RECORDING_SESSION   8208.0                    416.00       1281
# 380346  RECORDING_SESSION  10260.0                         .       1281
# 380347  RECORDING_SESSION   6156.0                         .       1281
# 380348  RECORDING_SESSION   8208.0                    439.00       1281
# 380349  RECORDING_SESSION   8316.0                         .       1281
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  \
# 0                   0           0.0000  ...
# 1                 165           0.0280  ...
# 2                   0           0.0000  ...
# 3                   0           0.0000  ...
# 4                 184           0.0313  ...
# ...               ...              ...  ...
# 380345            258           0.0426  ...
# 380346              0           0.0000  ...
# 380347              0           0.0000  ...
# 380348            209           0.0345  ...
# 380349              0           0.0000  ...
#
#                                                 a_tokens  \
# 0          [A, company, that, will, soon, sell, e-bikes]
# 1          [A, company, that, will, soon, sell, e-bikes]
# 2          [A, company, that, will, soon, sell, e-bikes]
# 3          [A, company, that, will, soon, sell, e-bikes]
# 4          [A, company, that, will, soon, sell, e-bikes]
# ...                                                  ...
# 380345  [He, is, a, lobbyist, who, works, for, the, BPI]
# 380346  [He, is, a, lobbyist, who, works, for, the, BPI]
# 380347  [He, is, a, lobbyist, who, works, for, the, BPI]
# 380348  [He, is, a, lobbyist, who, works, for, the, BPI]
# 380349  [He, is, a, lobbyist, who, works, for, the, BPI]
#
#                                                  b_tokens  \
# 0           [A, company, founded, nearly, 20, years, ago]
# 1           [A, company, founded, nearly, 20, years, ago]
# 2           [A, company, founded, nearly, 20, years, ago]
# 3           [A, company, founded, nearly, 20, years, ago]
# 4           [A, company, founded, nearly, 20, years, ago]
# ...                                                   ...
# 380345  [He, is, a, politician, who, is, endorsed, by,...
# 380346  [He, is, a, politician, who, is, endorsed, by,...
# 380347  [He, is, a, politician, who, is, endorsed, by,...
# 380348  [He, is, a, politician, who, is, endorsed, by,...
# 380349  [He, is, a, politician, who, is, endorsed, by,...
#
#                                                  c_tokens  \
# 0       [A, company, known, for, selling, non-electric...
# 1       [A, company, known, for, selling, non-electric...
# 2       [A, company, known, for, selling, non-electric...
# 3       [A, company, known, for, selling, non-electric...
# 4       [A, company, known, for, selling, non-electric...
# ...                                                   ...
# 380345  [He, is, a, resident, of, Downing, Street, who...
# 380346  [He, is, a, resident, of, Downing, Street, who...
# 380347  [He, is, a, resident, of, Downing, Street, who...
# 380348  [He, is, a, resident, of, Downing, Street, who...
# 380349  [He, is, a, resident, of, Downing, Street, who...
#
#                                                  d_tokens question_len a_len  \
# 0        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 1        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 2        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 3        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 4        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# ...                                                   ...          ...   ...
# 380345  [He, is, a, conservative, businessman, who, is...           12     9
# 380346  [He, is, a, conservative, businessman, who, is...           12     9
# 380347  [He, is, a, conservative, businessman, who, is...           12     9
# 380348  [He, is, a, conservative, businessman, who, is...           12     9
# 380349  [He, is, a, conservative, businessman, who, is...           12     9
#
#        b_len c_len d_len area_label
# 0          7     7     8   question
# 1          7     7     8   question
# 2          7     7     8   question
# 3          7     7     8   question
# 4          7     7     8   answer_1
# ...      ...   ...   ...        ...
# 380345    10    14    12   answer_4
# 380346    10    14    12   answer_4
# 380347    10    14    12   answer_4
# 380348    10    14    12   answer_4
# 380349    10    14    12   answer_4
#
# [380350 rows x 179 columns]

# %%
def generate_new_row_features(functions, df, join_columns=['TRIAL_INDEX', 'participant_id', 'area_label']):
    result_df = df.copy()

    for func in functions:
        print(func)
        new_features_df = func(df)
        result_df = result_df.merge(new_features_df, on=join_columns, how='left')
        print(result_df)

    return result_df

# %%
per_row_feature_generators = [create_mean_area_dwell_time, create_mean_area_fixation_count,
                              create_mean_first_fixation_duration, create_skip_rate]
df_with_features_h = generate_new_row_features(per_row_feature_generators, df_base_features_h)
df_with_features_g = generate_new_row_features(per_row_feature_generators, df_base_features_g)
# Out:
# <function create_mean_area_dwell_time at 0x000001975CDC20E0>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 4       l42_2070        RIGHT       Right
# 1                 4       l42_2070        RIGHT       Right
# 2                 4       l42_2070        RIGHT       Right
# 3                 4       l42_2070        RIGHT       Right
# 4                 4       l42_2070        RIGHT       Right
# ...             ...            ...          ...         ...
# 380345           59         l10_39         LEFT        Left
# 380346           59         l10_39         LEFT        Left
# 380347           59         l10_39         LEFT        Left
# 380348           59         l10_39         LEFT        Left
# 380349           59         l10_39         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10165.0                         .        261
# 1       RECORDING_SESSION   6099.0                   1078.00        261
# 2       RECORDING_SESSION  14231.0                         .        261
# 3       RECORDING_SESSION  28569.0                         .        261
# 4       RECORDING_SESSION   4180.0                   1139.00        492
# ...                   ...      ...                       ...        ...
# 380345  RECORDING_SESSION   8208.0                    416.00       1281
# 380346  RECORDING_SESSION  10260.0                         .       1281
# 380347  RECORDING_SESSION   6156.0                         .       1281
# 380348  RECORDING_SESSION   8208.0                    439.00       1281
# 380349  RECORDING_SESSION   8316.0                         .       1281
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  \
# 0                   0           0.0000  ...
# 1                 165           0.0280  ...
# 2                   0           0.0000  ...
# 3                   0           0.0000  ...
# 4                 184           0.0313  ...
# ...               ...              ...  ...
# 380345            258           0.0426  ...
# 380346              0           0.0000  ...
# 380347              0           0.0000  ...
# 380348            209           0.0345  ...
# 380349              0           0.0000  ...
#
#                                                  b_tokens  \
# 0           [A, company, founded, nearly, 20, years, ago]
# 1           [A, company, founded, nearly, 20, years, ago]
# 2           [A, company, founded, nearly, 20, years, ago]
# 3           [A, company, founded, nearly, 20, years, ago]
# 4           [A, company, founded, nearly, 20, years, ago]
# ...                                                   ...
# 380345  [He, is, a, politician, who, is, endorsed, by,...
# 380346  [He, is, a, politician, who, is, endorsed, by,...
# 380347  [He, is, a, politician, who, is, endorsed, by,...
# 380348  [He, is, a, politician, who, is, endorsed, by,...
# 380349  [He, is, a, politician, who, is, endorsed, by,...
#
#                                                  c_tokens  \
# 0       [A, company, known, for, selling, non-electric...
# 1       [A, company, known, for, selling, non-electric...
# 2       [A, company, known, for, selling, non-electric...
# 3       [A, company, known, for, selling, non-electric...
# 4       [A, company, known, for, selling, non-electric...
# ...                                                   ...
# 380345  [He, is, a, resident, of, Downing, Street, who...
# 380346  [He, is, a, resident, of, Downing, Street, who...
# 380347  [He, is, a, resident, of, Downing, Street, who...
# 380348  [He, is, a, resident, of, Downing, Street, who...
# 380349  [He, is, a, resident, of, Downing, Street, who...
#
#                                                  d_tokens question_len a_len  \
# 0        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 1        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 2        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 3        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 4        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# ...                                                   ...          ...   ...
# 380345  [He, is, a, conservative, businessman, who, is...           12     9
# 380346  [He, is, a, conservative, businessman, who, is...           12     9
# 380347  [He, is, a, conservative, businessman, who, is...           12     9
# 380348  [He, is, a, conservative, businessman, who, is...           12     9
# 380349  [He, is, a, conservative, businessman, who, is...           12     9
#
#        b_len c_len d_len area_label mean_dwell_time
# 0          7     7     8   question       41.250000
# 1          7     7     8   question       41.250000
# 2          7     7     8   question       41.250000
# 3          7     7     8   question       41.250000
# 4          7     7     8   answer_1      173.000000
# ...      ...   ...   ...        ...             ...
# 380345    10    14    12   answer_4      142.833333
# 380346    10    14    12   answer_4      142.833333
# 380347    10    14    12   answer_4      142.833333
# 380348    10    14    12   answer_4      142.833333
# 380349    10    14    12   answer_4      142.833333
#
# [380350 rows x 180 columns]
# <function create_mean_area_fixation_count at 0x000001975CDC1D80>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 4       l42_2070        RIGHT       Right
# 1                 4       l42_2070        RIGHT       Right
# 2                 4       l42_2070        RIGHT       Right
# 3                 4       l42_2070        RIGHT       Right
# 4                 4       l42_2070        RIGHT       Right
# ...             ...            ...          ...         ...
# 380345           59         l10_39         LEFT        Left
# 380346           59         l10_39         LEFT        Left
# 380347           59         l10_39         LEFT        Left
# 380348           59         l10_39         LEFT        Left
# 380349           59         l10_39         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10165.0                         .        261
# 1       RECORDING_SESSION   6099.0                   1078.00        261
# 2       RECORDING_SESSION  14231.0                         .        261
# 3       RECORDING_SESSION  28569.0                         .        261
# 4       RECORDING_SESSION   4180.0                   1139.00        492
# ...                   ...      ...                       ...        ...
# 380345  RECORDING_SESSION   8208.0                    416.00       1281
# 380346  RECORDING_SESSION  10260.0                         .       1281
# 380347  RECORDING_SESSION   6156.0                         .       1281
# 380348  RECORDING_SESSION   8208.0                    439.00       1281
# 380349  RECORDING_SESSION   8316.0                         .       1281
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  \
# 0                   0           0.0000  ...
# 1                 165           0.0280  ...
# 2                   0           0.0000  ...
# 3                   0           0.0000  ...
# 4                 184           0.0313  ...
# ...               ...              ...  ...
# 380345            258           0.0426  ...
# 380346              0           0.0000  ...
# 380347              0           0.0000  ...
# 380348            209           0.0345  ...
# 380349              0           0.0000  ...
#
#                                                  c_tokens  \
# 0       [A, company, known, for, selling, non-electric...
# 1       [A, company, known, for, selling, non-electric...
# 2       [A, company, known, for, selling, non-electric...
# 3       [A, company, known, for, selling, non-electric...
# 4       [A, company, known, for, selling, non-electric...
# ...                                                   ...
# 380345  [He, is, a, resident, of, Downing, Street, who...
# 380346  [He, is, a, resident, of, Downing, Street, who...
# 380347  [He, is, a, resident, of, Downing, Street, who...
# 380348  [He, is, a, resident, of, Downing, Street, who...
# 380349  [He, is, a, resident, of, Downing, Street, who...
#
#                                                  d_tokens question_len a_len  \
# 0        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 1        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 2        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 3        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 4        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# ...                                                   ...          ...   ...
# 380345  [He, is, a, conservative, businessman, who, is...           12     9
# 380346  [He, is, a, conservative, businessman, who, is...           12     9
# 380347  [He, is, a, conservative, businessman, who, is...           12     9
# 380348  [He, is, a, conservative, businessman, who, is...           12     9
# 380349  [He, is, a, conservative, businessman, who, is...           12     9
#
#        b_len c_len d_len area_label mean_dwell_time mean_fixations_count
# 0          7     7     8   question       41.250000             0.250000
# 1          7     7     8   question       41.250000             0.250000
# 2          7     7     8   question       41.250000             0.250000
# 3          7     7     8   question       41.250000             0.250000
# 4          7     7     8   answer_1      173.000000             1.000000
# ...      ...   ...   ...        ...             ...                  ...
# 380345    10    14    12   answer_4      142.833333             0.666667
# 380346    10    14    12   answer_4      142.833333             0.666667
# 380347    10    14    12   answer_4      142.833333             0.666667
# 380348    10    14    12   answer_4      142.833333             0.666667
# 380349    10    14    12   answer_4      142.833333             0.666667
#
# [380350 rows x 181 columns]
# <function create_mean_first_fixation_duration at 0x0000019761CEFE20>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 4       l42_2070        RIGHT       Right
# 1                 4       l42_2070        RIGHT       Right
# 2                 4       l42_2070        RIGHT       Right
# 3                 4       l42_2070        RIGHT       Right
# 4                 4       l42_2070        RIGHT       Right
# ...             ...            ...          ...         ...
# 380345           59         l10_39         LEFT        Left
# 380346           59         l10_39         LEFT        Left
# 380347           59         l10_39         LEFT        Left
# 380348           59         l10_39         LEFT        Left
# 380349           59         l10_39         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10165.0                         .        261
# 1       RECORDING_SESSION   6099.0                   1078.00        261
# 2       RECORDING_SESSION  14231.0                         .        261
# 3       RECORDING_SESSION  28569.0                         .        261
# 4       RECORDING_SESSION   4180.0                   1139.00        492
# ...                   ...      ...                       ...        ...
# 380345  RECORDING_SESSION   8208.0                    416.00       1281
# 380346  RECORDING_SESSION  10260.0                         .       1281
# 380347  RECORDING_SESSION   6156.0                         .       1281
# 380348  RECORDING_SESSION   8208.0                    439.00       1281
# 380349  RECORDING_SESSION   8316.0                         .       1281
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  \
# 0                   0           0.0000  ...
# 1                 165           0.0280  ...
# 2                   0           0.0000  ...
# 3                   0           0.0000  ...
# 4                 184           0.0313  ...
# ...               ...              ...  ...
# 380345            258           0.0426  ...
# 380346              0           0.0000  ...
# 380347              0           0.0000  ...
# 380348            209           0.0345  ...
# 380349              0           0.0000  ...
#
#                                                  d_tokens question_len a_len  \
# 0        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 1        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 2        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 3        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# 4        [A, company, that, is, headed, by, Larry, Pizzi]            4     7
# ...                                                   ...          ...   ...
# 380345  [He, is, a, conservative, businessman, who, is...           12     9
# 380346  [He, is, a, conservative, businessman, who, is...           12     9
# 380347  [He, is, a, conservative, businessman, who, is...           12     9
# 380348  [He, is, a, conservative, businessman, who, is...           12     9
# 380349  [He, is, a, conservative, businessman, who, is...           12     9
#
#        b_len c_len d_len area_label mean_dwell_time mean_fixations_count  \
# 0          7     7     8   question       41.250000             0.250000
# 1          7     7     8   question       41.250000             0.250000
# 2          7     7     8   question       41.250000             0.250000
# 3          7     7     8   question       41.250000             0.250000
# 4          7     7     8   answer_1      173.000000             1.000000
# ...      ...   ...   ...        ...             ...                  ...
# 380345    10    14    12   answer_4      142.833333             0.666667
# 380346    10    14    12   answer_4      142.833333             0.666667
# 380347    10    14    12   answer_4      142.833333             0.666667
# 380348    10    14    12   answer_4      142.833333             0.666667
# 380349    10    14    12   answer_4      142.833333             0.666667
#
#        mean_first_fixation_duration
# 0                         41.250000
# 1                         41.250000
# 2                         41.250000
# 3                         41.250000
# 4                         94.285714
# ...                             ...
# 380345                    99.083333
# 380346                    99.083333
# 380347                    99.083333
# 380348                    99.083333
# 380349                    99.083333
#
# [380350 rows x 182 columns]
# <function create_skip_rate at 0x000001975CDC1FC0>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 4       l42_2070        RIGHT       Right
# 1                 4       l42_2070        RIGHT       Right
# 2                 4       l42_2070        RIGHT       Right
# 3                 4       l42_2070        RIGHT       Right
# 4                 4       l42_2070        RIGHT       Right
# ...             ...            ...          ...         ...
# 380345           59         l10_39         LEFT        Left
# 380346           59         l10_39         LEFT        Left
# 380347           59         l10_39         LEFT        Left
# 380348           59         l10_39         LEFT        Left
# 380349           59         l10_39         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10165.0                         .        261
# 1       RECORDING_SESSION   6099.0                   1078.00        261
# 2       RECORDING_SESSION  14231.0                         .        261
# 3       RECORDING_SESSION  28569.0                         .        261
# 4       RECORDING_SESSION   4180.0                   1139.00        492
# ...                   ...      ...                       ...        ...
# 380345  RECORDING_SESSION   8208.0                    416.00       1281
# 380346  RECORDING_SESSION  10260.0                         .       1281
# 380347  RECORDING_SESSION   6156.0                         .       1281
# 380348  RECORDING_SESSION   8208.0                    439.00       1281
# 380349  RECORDING_SESSION   8316.0                         .       1281
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  question_len a_len b_len c_len  \
# 0                   0           0.0000  ...             4     7     7     7
# 1                 165           0.0280  ...             4     7     7     7
# 2                   0           0.0000  ...             4     7     7     7
# 3                   0           0.0000  ...             4     7     7     7
# 4                 184           0.0313  ...             4     7     7     7
# ...               ...              ...  ...           ...   ...   ...   ...
# 380345            258           0.0426  ...            12     9    10    14
# 380346              0           0.0000  ...            12     9    10    14
# 380347              0           0.0000  ...            12     9    10    14
# 380348            209           0.0345  ...            12     9    10    14
# 380349              0           0.0000  ...            12     9    10    14
#
#        d_len area_label mean_dwell_time mean_fixations_count  \
# 0          8   question       41.250000             0.250000
# 1          8   question       41.250000             0.250000
# 2          8   question       41.250000             0.250000
# 3          8   question       41.250000             0.250000
# 4          8   answer_1      173.000000             1.000000
# ...      ...        ...             ...                  ...
# 380345    12   answer_4      142.833333             0.666667
# 380346    12   answer_4      142.833333             0.666667
# 380347    12   answer_4      142.833333             0.666667
# 380348    12   answer_4      142.833333             0.666667
# 380349    12   answer_4      142.833333             0.666667
#
#        mean_first_fixation_duration skip_rate
# 0                         41.250000  0.750000
# 1                         41.250000  0.750000
# 2                         41.250000  0.750000
# 3                         41.250000  0.750000
# 4                         94.285714  0.571429
# ...                             ...       ...
# 380345                    99.083333  0.666667
# 380346                    99.083333  0.666667
# 380347                    99.083333  0.666667
# 380348                    99.083333  0.666667
# 380349                    99.083333  0.666667
#
# [380350 rows x 183 columns]
# <function create_mean_area_dwell_time at 0x000001975CDC20E0>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 3        l59_485        RIGHT       Right
# 1                 3        l59_485        RIGHT       Right
# 2                 3        l59_485        RIGHT       Right
# 3                 3        l59_485        RIGHT       Right
# 4                 3        l59_485        RIGHT       Right
# ...             ...            ...          ...         ...
# 380273           65         l2_324         LEFT        Left
# 380274           65         l2_324         LEFT        Left
# 380275           65         l2_324         LEFT        Left
# 380276           65         l2_324         LEFT        Left
# 380277           65         l2_324         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10260.0                         .        261
# 1       RECORDING_SESSION   6156.0                         .        261
# 2       RECORDING_SESSION  18468.0                    711.00        261
# 3       RECORDING_SESSION  22572.0                         .        261
# 4       RECORDING_SESSION  16524.0                         .        261
# ...                   ...      ...                       ...        ...
# 380273  RECORDING_SESSION  12535.0                         .       1175
# 380274  RECORDING_SESSION  12768.0                         .       1287
# 380275  RECORDING_SESSION  10640.0                    921.00       1287
# 380276  RECORDING_SESSION   6384.0                    921.00       1287
# 380277  RECORDING_SESSION  10752.0                         .       1287
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  \
# 0                   0           0.0000  ...
# 1                   0           0.0000  ...
# 2                   9           0.0022  ...
# 3                   0           0.0000  ...
# 4                   0           0.0000  ...
# ...               ...              ...  ...
# 380273              0           0.0000  ...
# 380274              0           0.0000  ...
# 380275            403           0.0736  ...
# 380276             90           0.0164  ...
# 380277              0           0.0000  ...
#
#                                                  b_tokens  \
# 0                                         [Central, Park]
# 1                                         [Central, Park]
# 2                                         [Central, Park]
# 3                                         [Central, Park]
# 4                                         [Central, Park]
# ...                                                   ...
# 380273  [The, children, labor, rates, in, Bangladesh, ...
# 380274  [The, children, labor, rates, in, Bangladesh, ...
# 380275  [The, children, labor, rates, in, Bangladesh, ...
# 380276  [The, children, labor, rates, in, Bangladesh, ...
# 380277  [The, children, labor, rates, in, Bangladesh, ...
#
#                                                  c_tokens  \
# 0                        [Cockrell's, apartment, complex]
# 1                        [Cockrell's, apartment, complex]
# 2                        [Cockrell's, apartment, complex]
# 3                        [Cockrell's, apartment, complex]
# 4                        [Cockrell's, apartment, complex]
# ...                                                   ...
# 380273  [1.3, million, children, are, employed, in, un...
# 380274  [1.3, million, children, are, employed, in, un...
# 380275  [1.3, million, children, are, employed, in, un...
# 380276  [1.3, million, children, are, employed, in, un...
# 380277  [1.3, million, children, are, employed, in, un...
#
#                                                  d_tokens question_len a_len  \
# 0               [Trump, International, Hotel, and, Tower]            5     3
# 1               [Trump, International, Hotel, and, Tower]            5     3
# 2               [Trump, International, Hotel, and, Tower]            5     3
# 3               [Trump, International, Hotel, and, Tower]            5     3
# 4               [Trump, International, Hotel, and, Tower]            5     3
# ...                                                   ...          ...   ...
# 380273  [1,540, children, were, able, to, leave, risky...            9     8
# 380274  [1,540, children, were, able, to, leave, risky...            9     8
# 380275  [1,540, children, were, able, to, leave, risky...            9     8
# 380276  [1,540, children, were, able, to, leave, risky...            9     8
# 380277  [1,540, children, were, able, to, leave, risky...            9     8
#
#        b_len c_len d_len area_label mean_dwell_time
# 0          2     3     5   question             1.8
# 1          2     3     5   question             1.8
# 2          2     3     5   question             1.8
# 3          2     3     5   question             1.8
# 4          2     3     5   question             1.8
# ...      ...   ...   ...        ...             ...
# 380273    12     9    10   answer_4           224.2
# 380274    12     9    10   answer_4           224.2
# 380275    12     9    10   answer_4           224.2
# 380276    12     9    10   answer_4           224.2
# 380277    12     9    10   answer_4           224.2
#
# [380278 rows x 180 columns]
# <function create_mean_area_fixation_count at 0x000001975CDC1D80>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 3        l59_485        RIGHT       Right
# 1                 3        l59_485        RIGHT       Right
# 2                 3        l59_485        RIGHT       Right
# 3                 3        l59_485        RIGHT       Right
# 4                 3        l59_485        RIGHT       Right
# ...             ...            ...          ...         ...
# 380273           65         l2_324         LEFT        Left
# 380274           65         l2_324         LEFT        Left
# 380275           65         l2_324         LEFT        Left
# 380276           65         l2_324         LEFT        Left
# 380277           65         l2_324         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10260.0                         .        261
# 1       RECORDING_SESSION   6156.0                         .        261
# 2       RECORDING_SESSION  18468.0                    711.00        261
# 3       RECORDING_SESSION  22572.0                         .        261
# 4       RECORDING_SESSION  16524.0                         .        261
# ...                   ...      ...                       ...        ...
# 380273  RECORDING_SESSION  12535.0                         .       1175
# 380274  RECORDING_SESSION  12768.0                         .       1287
# 380275  RECORDING_SESSION  10640.0                    921.00       1287
# 380276  RECORDING_SESSION   6384.0                    921.00       1287
# 380277  RECORDING_SESSION  10752.0                         .       1287
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  \
# 0                   0           0.0000  ...
# 1                   0           0.0000  ...
# 2                   9           0.0022  ...
# 3                   0           0.0000  ...
# 4                   0           0.0000  ...
# ...               ...              ...  ...
# 380273              0           0.0000  ...
# 380274              0           0.0000  ...
# 380275            403           0.0736  ...
# 380276             90           0.0164  ...
# 380277              0           0.0000  ...
#
#                                                  c_tokens  \
# 0                        [Cockrell's, apartment, complex]
# 1                        [Cockrell's, apartment, complex]
# 2                        [Cockrell's, apartment, complex]
# 3                        [Cockrell's, apartment, complex]
# 4                        [Cockrell's, apartment, complex]
# ...                                                   ...
# 380273  [1.3, million, children, are, employed, in, un...
# 380274  [1.3, million, children, are, employed, in, un...
# 380275  [1.3, million, children, are, employed, in, un...
# 380276  [1.3, million, children, are, employed, in, un...
# 380277  [1.3, million, children, are, employed, in, un...
#
#                                                  d_tokens question_len a_len  \
# 0               [Trump, International, Hotel, and, Tower]            5     3
# 1               [Trump, International, Hotel, and, Tower]            5     3
# 2               [Trump, International, Hotel, and, Tower]            5     3
# 3               [Trump, International, Hotel, and, Tower]            5     3
# 4               [Trump, International, Hotel, and, Tower]            5     3
# ...                                                   ...          ...   ...
# 380273  [1,540, children, were, able, to, leave, risky...            9     8
# 380274  [1,540, children, were, able, to, leave, risky...            9     8
# 380275  [1,540, children, were, able, to, leave, risky...            9     8
# 380276  [1,540, children, were, able, to, leave, risky...            9     8
# 380277  [1,540, children, were, able, to, leave, risky...            9     8
#
#        b_len c_len d_len area_label mean_dwell_time mean_fixations_count
# 0          2     3     5   question             1.8                  0.2
# 1          2     3     5   question             1.8                  0.2
# 2          2     3     5   question             1.8                  0.2
# 3          2     3     5   question             1.8                  0.2
# 4          2     3     5   question             1.8                  0.2
# ...      ...   ...   ...        ...             ...                  ...
# 380273    12     9    10   answer_4           224.2                  1.1
# 380274    12     9    10   answer_4           224.2                  1.1
# 380275    12     9    10   answer_4           224.2                  1.1
# 380276    12     9    10   answer_4           224.2                  1.1
# 380277    12     9    10   answer_4           224.2                  1.1
#
# [380278 rows x 181 columns]
# <function create_mean_first_fixation_duration at 0x0000019761CEFE20>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 3        l59_485        RIGHT       Right
# 1                 3        l59_485        RIGHT       Right
# 2                 3        l59_485        RIGHT       Right
# 3                 3        l59_485        RIGHT       Right
# 4                 3        l59_485        RIGHT       Right
# ...             ...            ...          ...         ...
# 380273           65         l2_324         LEFT        Left
# 380274           65         l2_324         LEFT        Left
# 380275           65         l2_324         LEFT        Left
# 380276           65         l2_324         LEFT        Left
# 380277           65         l2_324         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10260.0                         .        261
# 1       RECORDING_SESSION   6156.0                         .        261
# 2       RECORDING_SESSION  18468.0                    711.00        261
# 3       RECORDING_SESSION  22572.0                         .        261
# 4       RECORDING_SESSION  16524.0                         .        261
# ...                   ...      ...                       ...        ...
# 380273  RECORDING_SESSION  12535.0                         .       1175
# 380274  RECORDING_SESSION  12768.0                         .       1287
# 380275  RECORDING_SESSION  10640.0                    921.00       1287
# 380276  RECORDING_SESSION   6384.0                    921.00       1287
# 380277  RECORDING_SESSION  10752.0                         .       1287
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  \
# 0                   0           0.0000  ...
# 1                   0           0.0000  ...
# 2                   9           0.0022  ...
# 3                   0           0.0000  ...
# 4                   0           0.0000  ...
# ...               ...              ...  ...
# 380273              0           0.0000  ...
# 380274              0           0.0000  ...
# 380275            403           0.0736  ...
# 380276             90           0.0164  ...
# 380277              0           0.0000  ...
#
#                                                  d_tokens question_len a_len  \
# 0               [Trump, International, Hotel, and, Tower]            5     3
# 1               [Trump, International, Hotel, and, Tower]            5     3
# 2               [Trump, International, Hotel, and, Tower]            5     3
# 3               [Trump, International, Hotel, and, Tower]            5     3
# 4               [Trump, International, Hotel, and, Tower]            5     3
# ...                                                   ...          ...   ...
# 380273  [1,540, children, were, able, to, leave, risky...            9     8
# 380274  [1,540, children, were, able, to, leave, risky...            9     8
# 380275  [1,540, children, were, able, to, leave, risky...            9     8
# 380276  [1,540, children, were, able, to, leave, risky...            9     8
# 380277  [1,540, children, were, able, to, leave, risky...            9     8
#
#        b_len c_len d_len area_label mean_dwell_time mean_fixations_count  \
# 0          2     3     5   question             1.8                  0.2
# 1          2     3     5   question             1.8                  0.2
# 2          2     3     5   question             1.8                  0.2
# 3          2     3     5   question             1.8                  0.2
# 4          2     3     5   question             1.8                  0.2
# ...      ...   ...   ...        ...             ...                  ...
# 380273    12     9    10   answer_4           224.2                  1.1
# 380274    12     9    10   answer_4           224.2                  1.1
# 380275    12     9    10   answer_4           224.2                  1.1
# 380276    12     9    10   answer_4           224.2                  1.1
# 380277    12     9    10   answer_4           224.2                  1.1
#
#        mean_first_fixation_duration
# 0                               1.8
# 1                               1.8
# 2                               1.8
# 3                               1.8
# 4                               1.8
# ...                             ...
# 380273                        153.4
# 380274                        153.4
# 380275                        153.4
# 380276                        153.4
# 380277                        153.4
#
# [380278 rows x 182 columns]
# <function create_skip_rate at 0x000001975CDC1FC0>
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 3        l59_485        RIGHT       Right
# 1                 3        l59_485        RIGHT       Right
# 2                 3        l59_485        RIGHT       Right
# 3                 3        l59_485        RIGHT       Right
# 4                 3        l59_485        RIGHT       Right
# ...             ...            ...          ...         ...
# 380273           65         l2_324         LEFT        Left
# 380274           65         l2_324         LEFT        Left
# 380275           65         l2_324         LEFT        Left
# 380276           65         l2_324         LEFT        Left
# 380277           65         l2_324         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10260.0                         .        261
# 1       RECORDING_SESSION   6156.0                         .        261
# 2       RECORDING_SESSION  18468.0                    711.00        261
# 3       RECORDING_SESSION  22572.0                         .        261
# 4       RECORDING_SESSION  16524.0                         .        261
# ...                   ...      ...                       ...        ...
# 380273  RECORDING_SESSION  12535.0                         .       1175
# 380274  RECORDING_SESSION  12768.0                         .       1287
# 380275  RECORDING_SESSION  10640.0                    921.00       1287
# 380276  RECORDING_SESSION   6384.0                    921.00       1287
# 380277  RECORDING_SESSION  10752.0                         .       1287
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  question_len a_len b_len c_len  \
# 0                   0           0.0000  ...             5     3     2     3
# 1                   0           0.0000  ...             5     3     2     3
# 2                   9           0.0022  ...             5     3     2     3
# 3                   0           0.0000  ...             5     3     2     3
# 4                   0           0.0000  ...             5     3     2     3
# ...               ...              ...  ...           ...   ...   ...   ...
# 380273              0           0.0000  ...             9     8    12     9
# 380274              0           0.0000  ...             9     8    12     9
# 380275            403           0.0736  ...             9     8    12     9
# 380276             90           0.0164  ...             9     8    12     9
# 380277              0           0.0000  ...             9     8    12     9
#
#        d_len area_label mean_dwell_time mean_fixations_count  \
# 0          5   question             1.8                  0.2
# 1          5   question             1.8                  0.2
# 2          5   question             1.8                  0.2
# 3          5   question             1.8                  0.2
# 4          5   question             1.8                  0.2
# ...      ...        ...             ...                  ...
# 380273    10   answer_4           224.2                  1.1
# 380274    10   answer_4           224.2                  1.1
# 380275    10   answer_4           224.2                  1.1
# 380276    10   answer_4           224.2                  1.1
# 380277    10   answer_4           224.2                  1.1
#
#        mean_first_fixation_duration skip_rate
# 0                               1.8       0.8
# 1                               1.8       0.8
# 2                               1.8       0.8
# 3                               1.8       0.8
# 4                               1.8       0.8
# ...                             ...       ...
# 380273                        153.4       0.6
# 380274                        153.4       0.6
# 380275                        153.4       0.6
# 380276                        153.4       0.6
# 380277                        153.4       0.6
#
# [380278 rows x 183 columns]

# %%
df_with_features_h
# Out:
#         TRIAL_INDEX participant_id EYE_REPORTED EYE_TRACKED  \
# 0                 4       l42_2070        RIGHT       Right
# 1                 4       l42_2070        RIGHT       Right
# 2                 4       l42_2070        RIGHT       Right
# 3                 4       l42_2070        RIGHT       Right
# 4                 4       l42_2070        RIGHT       Right
# ...             ...            ...          ...         ...
# 380345           59         l10_39         LEFT        Left
# 380346           59         l10_39         LEFT        Left
# 380347           59         l10_39         LEFT        Left
# 380348           59         l10_39         LEFT        Left
# 380349           59         l10_39         LEFT        Left
#
#        GROUPING_VARIABLES  IA_AREA IA_AVERAGE_FIX_PUPIL_SIZE  IA_BOTTOM  \
# 0       RECORDING_SESSION  10165.0                         .        261
# 1       RECORDING_SESSION   6099.0                   1078.00        261
# 2       RECORDING_SESSION  14231.0                         .        261
# 3       RECORDING_SESSION  28569.0                         .        261
# 4       RECORDING_SESSION   4180.0                   1139.00        492
# ...                   ...      ...                       ...        ...
# 380345  RECORDING_SESSION   8208.0                    416.00       1281
# 380346  RECORDING_SESSION  10260.0                         .       1281
# 380347  RECORDING_SESSION   6156.0                         .       1281
# 380348  RECORDING_SESSION   8208.0                    439.00       1281
# 380349  RECORDING_SESSION   8316.0                         .       1281
#
#         IA_DWELL_TIME  IA_DWELL_TIME_%  ...  question_len a_len b_len c_len  \
# 0                   0           0.0000  ...             4     7     7     7
# 1                 165           0.0280  ...             4     7     7     7
# 2                   0           0.0000  ...             4     7     7     7
# 3                   0           0.0000  ...             4     7     7     7
# 4                 184           0.0313  ...             4     7     7     7
# ...               ...              ...  ...           ...   ...   ...   ...
# 380345            258           0.0426  ...            12     9    10    14
# 380346              0           0.0000  ...            12     9    10    14
# 380347              0           0.0000  ...            12     9    10    14
# 380348            209           0.0345  ...            12     9    10    14
# 380349              0           0.0000  ...            12     9    10    14
#
#        d_len area_label mean_dwell_time mean_fixations_count  \
# 0          8   question       41.250000             0.250000
# 1          8   question       41.250000             0.250000
# 2          8   question       41.250000             0.250000
# 3          8   question       41.250000             0.250000
# 4          8   answer_1      173.000000             1.000000
# ...      ...        ...             ...                  ...
# 380345    12   answer_4      142.833333             0.666667
# 380346    12   answer_4      142.833333             0.666667
# 380347    12   answer_4      142.833333             0.666667
# 380348    12   answer_4      142.833333             0.666667
# 380349    12   answer_4      142.833333             0.666667
#
#        mean_first_fixation_duration skip_rate
# 0                         41.250000  0.750000
# 1                         41.250000  0.750000
# 2                         41.250000  0.750000
# 3                         41.250000  0.750000
# 4                         94.285714  0.571429
# ...                             ...       ...
# 380345                    99.083333  0.666667
# 380346                    99.083333  0.666667
# 380347                    99.083333  0.666667
# 380348                    99.083333  0.666667
# 380349                    99.083333  0.666667
#
# [380350 rows x 183 columns]
