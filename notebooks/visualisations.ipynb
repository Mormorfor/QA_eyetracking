# %%
import pandas as pd

from src import constants as C
from src.viz import visualisations as V

from importlib import reload
reload(V)
# Out:
# <module 'src.viz.visualisations' from 'C:\\Users\\deeth\\PycharmProjects\\QA_eyetracking\\src\\viz\\visualisations.py'>

# %%
hunters = pd.read_csv('../data/hunters.csv')
gatherers = pd.read_csv('../data/gatherers.csv')

# %%
V.run_all_area_metric_plots(hunters, gatherers,save=True)

# %%
results = V.run_all_area_barplots(
    hunters,
    gatherers,
    save_plots=True,
)

# %%
V.run_all_simplified_visit_matrices(
    hunters=hunters,
    gatherers=gatherers,
    kinds=("label", "location"),
    which_list=("first", "last"),
    save=True,
    show=True,
)

# %%
strategy_results = V.run_all_strategy_plots(
    hunters=hunters,
    gatherers=gatherers,
    kind="location",
    window_len=4,
    threshold=0.5,
    save=True,
)
print(strategy_results["hunters"]["before_after_summary"])
print(strategy_results["gatherers"]["before_after_summary"])

# %%
time_segment_results = V.run_all_time_segment_plots(
    hunters=hunters,
    gatherers=gatherers,
    group_cols=(C.PARTICIPANT_ID, C.TRIAL_ID),
    area_col=C.AREA_LABEL_COLUMN,
    selected_col=C.SELECTED_ANSWER_LABEL_COLUMN,
    dwell_col=C.IA_DWELL_TIME,
    fix_col=C.IA_FIXATIONS_COUNT,
    segment_col=C.SEGMENT_COLUMN,
    save=True,
)

# %%
dominant_eye_strategy_results = V.run_dominant_strategy_eye_analysis(
    hunters=hunters,
    gatherers=gatherers,
    kind="location",
    window_len=4,
    drop_question=True,
    threshold=0.5,
    output_root="../reports/plots/dominant_eye",
    save=True,
)

dominant_eye_strategy_results["hunters"]["crosstab"]

# %%
res = V.run_all_matching_correctness_plots(
    hunters=hunters,
    gatherers=gatherers,
    output_root="../reports/plots/matching_correctness",
    save_plots=True,
    print_summaries=False,
)

# %%
len_results  = V.run_all_correctness_seq_len_threshold_plots(
    hunters=hunters,
    gatherers=gatherers,
    thresholds=(2, 3, 4, 5, 6, 7),
    save_plots=True,
    print_summaries=True,
)
# Out:
# === HUNTERS — threshold: 2 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 2   172        158  0.918605  0.868021  0.950898
# 1   > 2  9547       8291  0.868440  0.861512  0.875073
#
# === HUNTERS — threshold: 3 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 3   407        381  0.936118  0.908044  0.956036
# 1   > 3  9312       8068  0.866409  0.859348  0.873168
#
# === HUNTERS — threshold: 4 ===
#   group     n  k_correct  accuracy   ci_low   ci_high
# 0   ≤ 4  1383       1284  0.928416  0.91361  0.940850
# 1   > 4  8336       7165  0.859525  0.85190  0.866819
#
# === HUNTERS — threshold: 5 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 5  3683       3419  0.928319  0.919534  0.936212
# 1   > 5  6036       5030  0.833333  0.823720  0.842523
#
# === HUNTERS — threshold: 6 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 6  5679       5220  0.919176  0.911800  0.925985
# 1   > 6  4040       3229  0.799257  0.786624  0.811322
#
# === HUNTERS — threshold: 7 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 7  6822       6200  0.908824  0.901761  0.915427
# 1   > 7  2897       2249  0.776320  0.760785  0.791123
#
# === GATHERERS — threshold: 2 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 2   127        107  0.842520  0.769243  0.895683
# 1   > 2  9590       7783  0.811575  0.803624  0.819276
#
# === GATHERERS — threshold: 3 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 3   307        275  0.895765  0.856554  0.925194
# 1   > 3  9410       7615  0.809245  0.801181  0.817057
#
# === GATHERERS — threshold: 4 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 4  1207       1094  0.906379  0.888632  0.921549
# 1   > 4  8510       6796  0.798590  0.789935  0.806975
#
# === GATHERERS — threshold: 5 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 5  3349       3006  0.897581  0.886853  0.907399
# 1   > 5  6368       4884  0.766960  0.756417  0.777181
#
# === GATHERERS — threshold: 6 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 6  5249       4651  0.886074  0.877194  0.894388
# 1   > 6  4468       3239  0.724933  0.711650  0.737829
#
# === GATHERERS — threshold: 7 ===
#   group     n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 7  6424       5608  0.872976  0.864610  0.880897
# 1   > 7  3293       2282  0.692985  0.677013  0.708507
#
# === ALL_PARTICIPANTS — threshold: 2 ===
#   group      n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 2    299        265  0.886288  0.845298  0.917477
# 1   > 2  19137      16074  0.839944  0.834680  0.845070
#
# === ALL_PARTICIPANTS — threshold: 3 ===
#   group      n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 3    714        656  0.918768  0.896416  0.936637
# 1   > 3  18722      15683  0.837678  0.832326  0.842890
#
# === ALL_PARTICIPANTS — threshold: 4 ===
#   group      n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 4   2590       2378  0.918147  0.906959  0.928096
# 1   > 4  16846      13961  0.828743  0.822979  0.834357
#
# === ALL_PARTICIPANTS — threshold: 5 ===
#   group      n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 5   7032       6425  0.913680  0.906888  0.920021
# 1   > 5  12404       9914  0.799258  0.792117  0.806214
#
# === ALL_PARTICIPANTS — threshold: 6 ===
#   group      n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 6  10928       9871  0.903276  0.897591  0.908677
# 1   > 6   8508       6468  0.760226  0.751037  0.769179
#
# === ALL_PARTICIPANTS — threshold: 7 ===
#   group      n  k_correct  accuracy    ci_low   ci_high
# 0   ≤ 7  13246      11808  0.891439  0.886027  0.896624
# 1   > 7   6190       4531  0.731987  0.720811  0.742875

# %%
pattern_res_aba = V.run_all_back_and_forth_pattern_plots(
    hunters=hunters,
    gatherers=gatherers,
    save_plots=True,
    print_summaries=True,
    use_abab=False,
)
# Out:
# === HUNTERS — pattern: ABA ===
#          group     n  k_correct  accuracy    ci_low   ci_high
# 0   ABA absent  7434       6551  0.881221  0.873669  0.888380
# 1  ABA present  2285       1898  0.830635  0.814703  0.845456
# Fisher p=5.739e-305, OR=0.6658
#
# === GATHERERS — pattern: ABA ===
#          group     n  k_correct  accuracy    ci_low   ci_high
# 0   ABA absent  7326       6060  0.827191  0.818362  0.835677
# 1  ABA present  2391       1830  0.765370  0.747967  0.781922
# Fisher p=0, OR=0.6696
#
# === ALL_PARTICIPANTS — pattern: ABA ===
#          group      n  k_correct  accuracy    ci_low   ci_high
# 0   ABA absent  14760      12611  0.854404  0.848621  0.860002
# 1  ABA present   4676       3728  0.797263  0.785497  0.808540
# Fisher p=0, OR=0.6657

# %%
pattern_res_abab = V.run_all_back_and_forth_pattern_plots(
    hunters=hunters,
    gatherers=gatherers,
    save_plots=True,
    print_summaries=True,
    use_abab=True,
)
# Out:
# === HUNTERS — pattern: ABAB ===
#           group     n  k_correct  accuracy    ci_low   ci_high
# 0   ABAB absent  9189       8038  0.874742  0.867816  0.881353
# 1  ABAB present   530        411  0.775472  0.738037  0.808942
# Fisher p=7.586e-320, OR=0.4928
#
# === GATHERERS — pattern: ABAB ===
#           group     n  k_correct  accuracy    ci_low   ci_high
# 0   ABAB absent  9202       7511  0.816236  0.808191  0.824016
# 1  ABAB present   515        379  0.735922  0.696202  0.772149
# Fisher p=1.098e-160, OR=0.6249
#
# === ALL_PARTICIPANTS — pattern: ABAB ===
#           group      n  k_correct  accuracy    ci_low   ci_high
# 0   ABAB absent  18391      15549  0.845468  0.840172  0.850620
# 1  ABAB present   1045        790  0.755981  0.729033  0.781054
# Fisher p=0, OR=0.5628

# %%
trial_dwell_results = V.run_all_trial_mean_dwell_threshold_plots(
    hunters=hunters,
    gatherers=gatherers,
    thresholds=(100, 150, 200, 250, 300, 350, 400),
    save_plots=True,
    print_summaries=True,
)
# Out:
# === HUNTERS — threshold: 100 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 100.0  4927       4548  0.923077  0.915302  0.930192
# 1  > 100.0  4792       3901  0.814065  0.802799  0.824828
# Fisher p=0, OR=2.729
#
# === HUNTERS — threshold: 150 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 150.0  7559       6866  0.908321  0.901607  0.914621
# 1  > 150.0  2160       1583  0.732870  0.713809  0.751105
# Fisher p=0, OR=3.658
#
# === HUNTERS — threshold: 200 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 200.0  8631       7713  0.893639  0.886959  0.899969
# 1  > 200.0  1088        736  0.676471  0.648093  0.703606
# Fisher p=0, OR=4.029
#
# === HUNTERS — threshold: 250 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 250.0  9127       8081  0.885395  0.878697  0.891769
# 1  > 250.0   592        368  0.621622  0.581888  0.659787
# Fisher p=0, OR=4.674
#
# === HUNTERS — threshold: 300 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 300.0  9384       8262  0.880435  0.873714  0.886844
# 1  > 300.0   335        187  0.558209  0.504668  0.610430
# Fisher p=0, OR=5.857
#
# === HUNTERS — threshold: 350 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 350.0  9514       8337  0.876288  0.869519  0.882752
# 1  > 350.0   205        112  0.546341  0.477962  0.613016
# Fisher p=0, OR=5.707
#
# === HUNTERS — threshold: 400 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 400.0  9580       8382  0.874948  0.868173  0.881422
# 1  > 400.0   139         67  0.482014  0.400553  0.564444
# Fisher p=0, OR=7.099
#
# === GATHERERS — threshold: 100 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 100.0  4078       3665  0.898725  0.889087  0.907613
# 1  > 100.0  5639       4225  0.749246  0.737766  0.760387
# Fisher p=0, OR=2.98
#
# === GATHERERS — threshold: 150 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 150.0  6790       5904  0.869514  0.861293  0.877318
# 1  > 150.0  2927       1986  0.678510  0.661366  0.695187
# Fisher p=0, OR=3.194
#
# === GATHERERS — threshold: 200 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 200.0  8214       6950  0.846116  0.838151  0.853758
# 1  > 200.0  1503        940  0.625416  0.600655  0.649537
# Fisher p=0, OR=3.29
#
# === GATHERERS — threshold: 250 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 250.0  8884       7404  0.833408  0.825516  0.841012
# 1  > 250.0   833        486  0.583433  0.549646  0.616455
# Fisher p=0, OR=3.556
#
# === GATHERERS — threshold: 300 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 300.0  9210       7616  0.826927  0.819065  0.834517
# 1  > 300.0   507        274  0.540434  0.496911  0.583348
# Fisher p=0, OR=4.239
#
# === GATHERERS — threshold: 350 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 350.0  9406       7723  0.821072  0.813195  0.828686
# 1  > 350.0   311        167  0.536977  0.481445  0.591608
# Fisher p=0, OR=4.046
#
# === GATHERERS — threshold: 400 ===
#      group     n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 400.0  9523       7781  0.817074  0.809182  0.824711
# 1  > 400.0   194        109  0.561856  0.491506  0.629803
# Fisher p=0, OR=3.41
#
# === ALL_PARTICIPANTS — threshold: 100 ===
#      group      n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 100.0   9005       8213  0.912049  0.906022  0.917724
# 1  > 100.0  10431       8126  0.779024  0.770960  0.786883
# Fisher p=0, OR=2.925
#
# === ALL_PARTICIPANTS — threshold: 150 ===
#      group      n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 150.0  14349      12770  0.889957  0.884732  0.894974
# 1  > 150.0   5087       3569  0.701592  0.688870  0.714010
# Fisher p=0, OR=3.469
#
# === ALL_PARTICIPANTS — threshold: 200 ===
#      group      n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 200.0  16845      14663  0.870466  0.865310  0.875453
# 1  > 200.0   2591       1676  0.646854  0.628246  0.665028
# Fisher p=0, OR=3.66
#
# === ALL_PARTICIPANTS — threshold: 250 ===
#      group      n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 250.0  18011      15485  0.859752  0.854604  0.864747
# 1  > 250.0   1425        854  0.599298  0.573620  0.624442
# Fisher p=0, OR=4.067
#
# === ALL_PARTICIPANTS — threshold: 300 ===
#      group      n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 300.0  18594      15878  0.853931  0.848782  0.858935
# 1  > 300.0    842        461  0.547506  0.513746  0.580835
# Fisher p=0, OR=4.955
#
# === ALL_PARTICIPANTS — threshold: 350 ===
#      group      n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 350.0  18920      16060  0.848837  0.843662  0.853871
# 1  > 350.0    516        279  0.540698  0.497556  0.583238
# Fisher p=0, OR=4.767
# C:\Users\deeth\PycharmProjects\QA_eyetracking\src\viz\visualisations_correctness_measures.py:694: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=figsize)
# === ALL_PARTICIPANTS — threshold: 400 ===
#      group      n  k_correct  accuracy    ci_low   ci_high
# 0  ≤ 400.0  19103      16163  0.846097  0.840911  0.851145
# 1  > 400.0    333        176  0.528529  0.474893  0.581514
# Fisher p=0, OR=4.739
