# %%
import pandas as pd

from src import constants as C
from src.viz import visualisations as V

from importlib import reload
reload(V)
# Out:
# <module 'src.viz.visualisations' from 'C:\\Users\\deeth\\PycharmProjects\\QA_eyetracking\\src\\viz\\visualisations.py'>

# %%
hunters = pd.read_csv('../data/hunters.csv')
gatherers = pd.read_csv('../data/gatherers.csv')

# %%
V.run_all_area_metric_plots(hunters, gatherers)

# %%
results = V.run_all_area_barplots(
    hunters,
    gatherers,
    save_plots=True,
)
# Out:
# C:\Users\deeth\PycharmProjects\QA_eyetracking\src\viz\visualisations_area_bars.py:67: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=figsize)

# %%
V.run_all_simplified_visit_matrices(
    hunters=hunters,
    gatherers=gatherers,
    drop_question=False,
    kinds=("label", "location"),
    which_list=("first", "last"),
    save=True,
    show=True,
)

# %%
strategy_results = V.run_all_strategy_plots(
    hunters=hunters,
    gatherers=gatherers,
    kind="location",
    window_len=4,
    threshold=0.5,
    save=True,
)
print(strategy_results["hunters"]["before_after_summary"])
print(strategy_results["gatherers"]["before_after_summary"])
# Out:
# 52.8% of hunters participants had a dominant strategy (>50% of trials) before completion.
# 55.0% of hunters participants had a dominant strategy (>50% of trials) after completion.
# C:\Users\deeth\PycharmProjects\QA_eyetracking\src\viz\visualisations_strategies.py:288: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 60.6% of gatherers participants had a dominant strategy (>50% of trials) before completion.
# 62.2% of gatherers participants had a dominant strategy (>50% of trials) after completion.
# C:\Users\deeth\PycharmProjects\QA_eyetracking\src\viz\visualisations_strategies.py:288: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# {'participants': 180, 'mean_raw': 0.5239168413696715, 'mean_completed': 0.5498427672955974, 'mean_delta': 0.02592592592592593, 'raw_≥50%': 55.00000000000001, 'comp_≥50%': 60.55555555555555, 'changed_label_n': 0, 'changed_label_pct': 0.0, 'mean_seq_pct_changed': 7.170781893004115, 'median_seq_pct_changed': 5.555555555555555}
# {'participants': 180, 'mean_raw': 0.5582828635763646, 'mean_completed': 0.5772206693066232, 'mean_delta': 0.018937805730258557, 'raw_≥50%': 65.55555555555556, 'comp_≥50%': 67.77777777777779, 'changed_label_n': 4, 'changed_label_pct': 2.2222222222222223, 'mean_seq_pct_changed': 5.03261122757978, 'median_seq_pct_changed': 3.7037037037037033}

# %%
time_segment_results = V.run_all_time_segment_plots(
    hunters=hunters,
    gatherers=gatherers,
    group_cols=(C.PARTICIPANT_ID, C.TRIAL_ID),
    area_col=C.AREA_LABEL_COLUMN,
    selected_col=C.SELECTED_ANSWER_LABEL_COLUMN,
    dwell_col=C.IA_DWELL_TIME,
    fix_col=C.IA_FIXATIONS_COUNT,
    segment_col=C.SEGMENT_COLUMN,
    save=True,
)

# %%
dominant_eye_strategy_results = V.run_dominant_strategy_eye_analysis(
    hunters=hunters,
    gatherers=gatherers,
    kind="location",
    window_len=4,
    drop_question=True,
    threshold=0.5,
    output_root="../reports/plots/dominant_eye",
    save=True,
)

dominant_eye_strategy_results["hunters"]["crosstab"]
# Out:
# EYE_TRACKED                                         Left  Right
# strategy_str
# answer_0(top) → answer_1(left) → answer_2(right...     1      3
# answer_0(top) → answer_1(left) → answer_3(botto...     9     12
# answer_0(top) → answer_2(right) → answer_3(bott...    21     52
# answer_1(left) → answer_0(top) → answer_2(right...     0      1
