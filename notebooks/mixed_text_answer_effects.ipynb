# %%
from src.statistics import mixed_text_answer_effects as M
from importlib import reload
reload(M)

from src import constants as C

# %%
merged_h, merged_g = M.load_merged_data(
    hunters_path="../data/merged_hunters.csv",
    gatherers_path="../data/merged_gatherers.csv",
)
# Out:
# Loading hunters data from: ../data/merged_hunters.csv
# Loading gatherers data from: ../data/merged_gatherers.csv

# %%
models_h_sep = M.fit_no_slopes_for_all_answers(merged_h, M.TERMS, separated=True)
models_g_sep = M.fit_no_slopes_for_all_answers(merged_g, M.TERMS, separated=True)

M.plot_fixed_effects(M.TERMS, models_h_sep, h_or_g="hunters", separated_label="answ_separated")
M.plot_fixed_effects(M.TERMS, models_g_sep, h_or_g="gatherers", separated_label="answ_separated")
# Out:
# Fitting model (separated by answer selected) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 8449	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -56020.931 	 AIC: 112055.862
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  13724.583  117.152
# participant_id  (Intercept)   2869.283   53.566
# Residual                     27618.130  166.187
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# Model failed to converge with max|grad| = 0.00295769 (tol = 0.002, component 1)
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 744	 Groups: {'text_id_with_q': 391.0, 'participant_id': 175.0}
#
# Log-likelihood: -5297.364 	 AIC: 10608.729
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  37471.833  193.576
# participant_id  (Intercept)   8613.242   92.808
# Residual                     54904.689  234.317
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 374	 Groups: {'text_id_with_q': 246.0, 'participant_id': 146.0}
#
# Log-likelihood: -2627.976 	 AIC: 5269.952
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  13019.782  114.104
# participant_id  (Intercept)   1635.825   40.445
# Residual                     64632.315  254.229
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 152	 Groups: {'text_id_with_q': 108.0, 'participant_id': 91.0}
#
# Log-likelihood: -1061.858 	 AIC: 2137.716
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  35528.710  188.491
# participant_id  (Intercept)    806.300   28.395
# Residual                     42249.463  205.547
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 7890	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -52590.429 	 AIC: 105194.858
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  16687.369  129.180
# participant_id  (Intercept)   3209.428   56.652
# Residual                     28922.188  170.065
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 1000	 Groups: {'text_id_with_q': 459.0, 'participant_id': 179.0}
#
# Log-likelihood: -7299.636 	 AIC: 14613.272
#
# Random effects:
#
#                        Name         Var      Std
# text_id_with_q  (Intercept)   26399.377  162.479
# participant_id  (Intercept)    6573.148   81.075
# Residual                     104620.759  323.451
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 568	 Groups: {'text_id_with_q': 331.0, 'participant_id': 169.0}
#
# Log-likelihood: -4023.737 	 AIC: 8061.474
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  28239.388  168.046
# participant_id  (Intercept)  11303.881  106.320
# Residual                     53538.099  231.383
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (separated by answer selected) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 259	 Groups: {'text_id_with_q': 175.0, 'participant_id': 130.0}
#
# Log-likelihood: -1821.118 	 AIC: 3656.236
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  34517.494  185.789
# participant_id  (Intercept)   7858.575   88.649
# Residual                     41267.470  203.144
#
# No random effect correlations specified
#
# Fixed effects:

# %%
models_h_all = M.fit_no_slopes_for_all_answers(merged_h, M.TERMS, separated=False)
models_g_all = M.fit_no_slopes_for_all_answers(merged_g, M.TERMS, separated=False)

M.plot_fixed_effects(M.TERMS, models_h_all, h_or_g="hunters", separated_label="all_answ")
M.plot_fixed_effects(M.TERMS, models_g_all, h_or_g="gatherers", separated_label="all_answ")
# Out:
# Fitting model (all) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -64588.586 	 AIC: 129191.173
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  12252.236  110.690
# participant_id  (Intercept)   2848.325   53.370
# Residual                     29241.383  171.001
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -63206.026 	 AIC: 126426.052
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   5594.404   74.796
# participant_id  (Intercept)   1186.426   34.445
# Residual                     23120.036  152.053
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -62019.597 	 AIC: 124053.194
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   4166.495   64.548
# participant_id  (Intercept)    882.701   29.710
# Residual                     18182.424  134.842
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9719	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -60874.716 	 AIC: 121763.431
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   4315.526   65.693
# participant_id  (Intercept)    738.371   27.173
# Residual                     14042.848  118.503
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer A: answer_A ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -65289.570 	 AIC: 130593.141
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)  14185.909  119.105
# participant_id  (Intercept)   2989.077   54.672
# Residual                     33938.573  184.224
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer B: answer_B ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -64697.445 	 AIC: 129408.891
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   9018.925   94.968
# participant_id  (Intercept)   1984.158   44.544
# Residual                     31027.605  176.147
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer C: answer_C ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -62554.213 	 AIC: 125122.427
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   5969.526   77.263
# participant_id  (Intercept)   1738.049   41.690
# Residual                     19794.633  140.693
#
# No random effect correlations specified
#
# Fixed effects:
#
# Fitting model (all) for answer D: answer_D ~ critical + distractor + outside + (1|participant_id) + (1|text_id_with_q)
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1|participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 9717	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -61827.341 	 AIC: 123668.682
#
# Random effects:
#
#                        Name        Var      Std
# text_id_with_q  (Intercept)   5382.082   73.363
# participant_id  (Intercept)   1297.979   36.027
# Residual                     17011.410  130.428
#
# No random effect correlations specified
#
# Fixed effects:

# %%
#Error bars - fit simple regression per participant?
# Also - % of significant participants.

# %%
models_h_sloped = {}
models_g_sloped = {}


#not enough observations if both values are true
sep = True
corr = False

for label in C.ANSWER_LABELS:
    m_h = M.build_model_with_slopes(
        merged_h,
        answer_label=label,
        terms=M.TERMS,
        separated=sep,
        correlated_slopes=corr,
    )
    models_h_sloped[label] = m_h
    M.plot_participant_effects(
        m_h, f"Answer {label}",
        M.TERMS, h_or_g="hunters",
        separated=sep,
        correlated_slopes=corr
        )

    m_g = M.build_model_with_slopes(
        merged_g,
        answer_label=label,
        terms=M.TERMS,
        separated=sep,
        correlated_slopes=corr,
    )
    models_g_sloped[label] = m_g
    M.plot_participant_effects(
        m_g, f"Answer {label}",
        M.TERMS, h_or_g="gatherers",
        separated=sep,
        correlated_slopes=corr
        )
# Out:
# Fitting random-slope model for answer A: answer_A ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# [1] "Model failed to converge with max|grad| = 5.25929 (tol = 0.002, component 1)"
# [2] " \n"
#
# [1] "Model is nearly unidentifiable: very large eigenvalue\n - Rescale variables?"
# [2] " \n"
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 8449	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -55998.677 	 AIC: 112017.353
#
# Random effects:
#
#                          Name        Var      Std
# text_id_with_q    (Intercept)  13828.493  117.595
# participant_id        outside      0.013    0.113
# participant_id.1   distractor      0.008    0.087
# participant_id.2     critical      0.016    0.128
# participant_id.3  (Intercept)   2991.774   54.697
# Residual                       27017.213  164.369
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer A: fixed effects (separated, uncorrelated) ===
# critical     β=0.099 ± 0.052  p=0.000255 ***
# distractor   β=0.028 ± 0.045  p=0.2184
# outside      β=0.117 ± 0.072  p=0.001631 **
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer A_hunters.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_intercept_hunters.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_critical_hunters.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_distractor_hunters.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_outside_hunters.png
# Fitting random-slope model for answer A: answer_A ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# unable to evaluate scaled gradient
#
# Model failed to converge: degenerate  Hessian with 1 negative eigenvalues
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_A~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 7890	 Groups: {'text_id_with_q': 970.0, 'participant_id': 180.0}
#
# Log-likelihood: -52699.991 	 AIC: 105419.983
#
# Random effects:
#
#                          Name        Var      Std
# text_id_with_q    (Intercept)  39633.714  199.082
# participant_id        outside      0.020    0.143
# participant_id.1   distractor      0.007    0.083
# participant_id.2     critical      0.053    0.229
# participant_id.3  (Intercept)     65.768    8.110
# Residual                       26603.336  163.105
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer A: fixed effects (separated, uncorrelated) ===
# critical     β=0.100 ± 0.066  p=0.003192 **
# distractor   β=0.042 ± 0.039  p=0.0332 *
# outside      β=0.162 ± 0.069  p=5.43e-06 ***
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer A_gatherers.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_intercept_gatherers.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_critical_gatherers.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_distractor_gatherers.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer A_outside_gatherers.png
# Fitting random-slope model for answer B: answer_B ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 744	 Groups: {'text_id_with_q': 391.0, 'participant_id': 175.0}
#
# Log-likelihood: -5290.204 	 AIC: 10600.408
#
# Random effects:
#
#                          Name        Var      Std
# text_id_with_q    (Intercept)  32374.416  179.929
# participant_id        outside      0.020    0.141
# participant_id.1   distractor      0.000    0.000
# participant_id.2     critical      0.392    0.626
# participant_id.3  (Intercept)   7351.332   85.740
# Residual                       46520.660  215.686
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer B: fixed effects (separated, uncorrelated) ===
# critical     β=0.326 ± 0.263  p=0.0159 *
# distractor   β=-0.254 ± 0.198  p=0.01272 *
# outside      β=0.305 ± 0.309  p=0.07515 .
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer B_hunters.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_intercept_hunters.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_critical_hunters.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_distractor_hunters.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_outside_hunters.png
# Fitting random-slope model for answer B: answer_B ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_B~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 1000	 Groups: {'text_id_with_q': 459.0, 'participant_id': 179.0}
#
# Log-likelihood: -7297.148 	 AIC: 14614.296
#
# Random effects:
#
#                          Name         Var      Std
# text_id_with_q    (Intercept)   25596.644  159.990
# participant_id        outside       0.000    0.000
# participant_id.1   distractor       0.000    0.000
# participant_id.2     critical       0.079    0.281
# participant_id.3  (Intercept)    6401.275   80.008
# Residual                       101376.554  318.397
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer B: fixed effects (separated, uncorrelated) ===
# critical     β=0.478 ± 0.228  p=6.987e-05 ***
# distractor   β=0.125 ± 0.193  p=0.2035
# outside      β=-0.119 ± 0.279  p=0.403
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer B_gatherers.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_intercept_gatherers.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_critical_gatherers.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_distractor_gatherers.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer B_outside_gatherers.png
# Fitting random-slope model for answer C: answer_C ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 374	 Groups: {'text_id_with_q': 246.0, 'participant_id': 146.0}
#
# Log-likelihood: -2627.039 	 AIC: 5274.079
#
# Random effects:
#
#                          Name        Var      Std
# text_id_with_q    (Intercept)  12457.568  111.613
# participant_id        outside      0.000    0.000
# participant_id.1   distractor      0.078    0.280
# participant_id.2     critical      0.000    0.000
# participant_id.3  (Intercept)   1539.315   39.234
# Residual                       61434.542  247.860
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer C: fixed effects (separated, uncorrelated) ===
# critical     β=0.284 ± 0.298  p=0.06272 .
# distractor   β=0.058 ± 0.261  p=0.6642
# outside      β=0.115 ± 0.416  p=0.5878
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer C_hunters.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_intercept_hunters.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_critical_hunters.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_distractor_hunters.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_outside_hunters.png
# Fitting random-slope model for answer C: answer_C ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# **NOTE**: Column for 'residuals' not created in model.data, but saved in model.resid only. This is because you have rows with NaNs in your data.
#
# **NOTE** Column for 'fits' not created in model.data, but saved in model.fits only. This is because you have rows with NaNs in your data.
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_C~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 568	 Groups: {'text_id_with_q': 331.0, 'participant_id': 169.0}
#
# Log-likelihood: -4013.376 	 AIC: 8046.751
#
# Random effects:
#
#                          Name        Var      Std
# text_id_with_q    (Intercept)  46026.616  214.538
# participant_id        outside      0.352    0.593
# participant_id.1   distractor      0.000    0.000
# participant_id.2     critical      0.000    0.000
# participant_id.3  (Intercept)    914.428   30.240
# Residual                       37019.377  192.404
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer C: fixed effects (separated, uncorrelated) ===
# critical     β=0.144 ± 0.257  p=0.2711
# distractor   β=-0.140 ± 0.176  p=0.1186
# outside      β=0.615 ± 0.365  p=0.001061 **
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer C_gatherers.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_intercept_gatherers.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_critical_gatherers.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_distractor_gatherers.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer C_outside_gatherers.png
# Fitting random-slope model for answer D: answer_D ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 152	 Groups: {'text_id_with_q': 108.0, 'participant_id': 91.0}
#
# Log-likelihood: -1060.984 	 AIC: 2141.968
#
# Random effects:
#
#                          Name        Var      Std
# text_id_with_q    (Intercept)  36413.400  190.823
# participant_id        outside      0.225    0.474
# participant_id.1   distractor      0.000    0.002
# participant_id.2     critical      0.000    0.000
# participant_id.3  (Intercept)      0.000    0.000
# Residual                       35499.130  188.412
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer D: fixed effects (separated, uncorrelated) ===
# critical     β=0.177 ± 0.477  p=0.469
# distractor   β=0.266 ± 0.415  p=0.212
# outside      β=0.267 ± 0.725  p=0.4726
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer D_hunters.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_intercept_hunters.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_critical_hunters.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_distractor_hunters.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_outside_hunters.png
# Fitting random-slope model for answer D: answer_D ~ critical + distractor + outside + (1 + critical + distractor + outside || participant_id) + (1 | text_id_with_q)
# boundary (singular) fit: see help('isSingular')
#
# Linear mixed model fit by REML [’lmerMod’]
# Formula: answer_D~critical+distractor+outside+(1+critical+distractor+outside||participant_id)+(1|text_id_with_q)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 259	 Groups: {'text_id_with_q': 175.0, 'participant_id': 130.0}
#
# Log-likelihood: -1809.257 	 AIC: 3638.514
#
# Random effects:
#
#                          Name        Var      Std
# text_id_with_q    (Intercept)  38882.471  197.186
# participant_id        outside      0.000    0.017
# participant_id.1   distractor      0.000    0.000
# participant_id.2     critical      0.563    0.750
# participant_id.3  (Intercept)   2273.702   47.683
# Residual                       18286.350  135.227
#
# No random effect correlations specified
#
# Fixed effects:
#
#
# === Answer D: fixed effects (separated, uncorrelated) ===
# critical     β=0.336 ± 0.435  p=0.1311
# distractor   β=0.045 ± 0.275  p=0.749
# outside      β=0.643 ± 0.503  p=0.01288 *
# Saved fixed-effects table to: ../reports/report_data/slopes\separated__uncorrelated\fixed_effects_Answer D_gatherers.csv
# Saved intercept plot to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_intercept_gatherers.png
# Saved slope plot for critical to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_critical_gatherers.png
# Saved slope plot for distractor to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_distractor_gatherers.png
# Saved slope plot for outside to: ../reports/plots/texts_to_answers/participant_effects\separated__uncorrelated\Answer D_outside_gatherers.png
