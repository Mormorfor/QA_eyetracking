# %%
from src.statistics import mixed_area_comparisons as M
from src import constants as Con

import pandas as pd

from importlib import reload
reload(M)
# Out:
# <module 'src.statistics.mixed_area_comparisons' from 'C:\\Users\\deeth\\PycharmProjects\\QA_eyetracking\\src\\statistics\\mixed_area_comparisons.py'>

# %%
hunters = pd.read_csv('../data/hunters.csv')
gatherers = pd.read_csv('../data/gatherers.csv')

# %%
results = M.run_all_area_mixed_models(
    hunters=hunters,
    gatherers=gatherers,
    metrics=Con.AREA_METRIC_COLUMNS,
    alpha=0.05,
    save_tables=True,
    tables_root="../reports/report_data/area_mixed_models",
    trial_cols=(Con.PARTICIPANT_ID, Con.TEXT_ID_COLUMN, Con.TRIAL_ID),
)
# Out:
# === HUNTERS — metric: mean_dwell_time ===
#
# --- HUNTERS, selected = A ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 241.239884 234.911443 247.568325
# answer_B C(area_label)[answer_B] 145.916102 139.587660 152.244543
# answer_C C(area_label)[answer_C] 126.101901 119.773459 132.430342
# answer_D C(area_label)[answer_D] 127.689155 121.360714 134.017596
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc     ci_low    ci_high   p_adj_holm sig
# answer_A answer_B       95.323782 1.845321 51.657015 0.000000e+00  91.707019  98.940545 0.000000e+00   ★
# answer_A answer_C      115.137983 1.845321 62.394550 0.000000e+00 111.521220 118.754746 0.000000e+00   ★
# answer_A answer_D      113.550729 1.845321 61.534399 0.000000e+00 109.933966 117.167492 0.000000e+00   ★
# answer_B answer_C       19.814201 1.845321 10.737535 6.783098e-27  16.197438  23.430964 2.034929e-26   ★
# answer_B answer_D       18.226947 1.845321  9.877385 5.217693e-23  14.610184  21.843710 1.043539e-22   ★
# answer_C answer_D       -1.587255 1.845321 -0.860151 3.897059e-01  -5.204018   2.029508 3.897059e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__A__pairwise.csv
#
# --- HUNTERS, selected = B ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 214.812826 194.714597 234.911055
# answer_B C(area_label)[answer_B] 334.834978 314.736748 354.933207
# answer_C C(area_label)[answer_C] 176.615294 156.517065 196.713523
# answer_D C(area_label)[answer_D] 180.836934 160.738704 200.935163
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc      ci_low     ci_high   p_adj_holm sig
# answer_B answer_C      158.219684 8.293529  19.077487 3.884967e-81  141.964666  174.474701 2.330980e-80   ★
# answer_B answer_D      153.998044 8.293529  18.568459 5.783976e-77  137.743026  170.253062 2.891988e-76   ★
# answer_A answer_B     -120.022152 8.293529 -14.471783 1.826735e-47 -136.277169 -103.767134 7.306941e-47   ★
# answer_A answer_C       38.197532 8.293529   4.605703 4.110743e-06   21.942514   54.452550 1.233223e-05   ★
# answer_A answer_D       33.975892 8.293529   4.096675 4.191265e-05   17.720875   50.230910 8.382531e-05   ★
# answer_C answer_D       -4.221640 8.293529  -0.509028 6.107325e-01  -20.476657   12.033378 6.107325e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__B__pairwise.csv
#
# --- HUNTERS, selected = C ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 245.538013 218.815357 272.260670
# answer_B C(area_label)[answer_B] 235.028006 208.305349 261.750662
# answer_C C(area_label)[answer_C] 347.292181 320.569525 374.014838
# answer_D C(area_label)[answer_D] 202.089203 175.366547 228.811860
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc      ci_low    ci_high   p_adj_holm sig
# answer_C answer_D      145.202978 12.77879 11.362811 6.405004e-30  120.157009 170.248947 3.843003e-29   ★
# answer_B answer_C     -112.264175 12.77879 -8.785196 1.560924e-18 -137.310144 -87.218207 7.804621e-18   ★
# answer_A answer_C     -101.754168 12.77879 -7.962739 1.682726e-15 -126.800137 -76.708199 6.730904e-15   ★
# answer_A answer_D       43.448810 12.77879  3.400072 6.736806e-04   18.402841  68.494779 2.021042e-03   ★
# answer_B answer_D       32.938803 12.77879  2.577615 9.948475e-03    7.892834  57.984772 1.989695e-02   ★
# answer_A answer_B       10.510007 12.77879  0.822457 4.108168e-01  -14.535962  35.555976 4.108168e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__C__pairwise.csv
#
# --- HUNTERS, selected = D ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 261.998964 220.819396 303.178533
# answer_B C(area_label)[answer_B] 235.809628 194.630060 276.989197
# answer_C C(area_label)[answer_C] 227.035247 185.855678 268.214816
# answer_D C(area_label)[answer_D] 375.081274 333.901705 416.260842
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j        se         t        p_unc      ci_low     ci_high   p_adj_holm sig
# answer_C answer_D     -148.046027 19.536237 -7.578022 3.508635e-14 -186.336347 -109.755707 2.105181e-13   ★
# answer_B answer_D     -139.271645 19.536237 -7.128888 1.011829e-12 -177.561966 -100.981325 5.059147e-12   ★
# answer_A answer_D     -113.082310 19.536237 -5.788336 7.108694e-09 -151.372630  -74.791989 2.843478e-08   ★
# answer_A answer_C       34.963717 19.536237  1.789685 7.350450e-02   -3.326603   73.254038 2.205135e-01
# answer_A answer_B       26.189336 19.536237  1.340552 1.800660e-01  -12.100984   64.479656 3.601321e-01
# answer_B answer_C        8.774381 19.536237  0.449134 6.533352e-01  -29.515939   47.064702 6.533352e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/hunters/hunters__D__pairwise.csv
#
# === HUNTERS — metric: mean_fixations_count ===
#
# --- HUNTERS, selected = A ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.210742 1.181197 1.240288
# answer_B C(area_label)[answer_B]  0.790762 0.761216 0.820308
# answer_C C(area_label)[answer_C]  0.692332 0.662786 0.721878
# answer_D C(area_label)[answer_D]  0.703908 0.674362 0.733453
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low  ci_high   p_adj_holm sig
# answer_A answer_B        0.419980 0.007667 54.777546 0.000000e+00  0.404953 0.435007 0.000000e+00   ★
# answer_A answer_C        0.518411 0.007667 67.615722 0.000000e+00  0.503384 0.533438 0.000000e+00   ★
# answer_A answer_D        0.506835 0.007667 66.105907 0.000000e+00  0.491808 0.521862 0.000000e+00   ★
# answer_B answer_C        0.098430 0.007667 12.838175 1.002084e-37  0.083403 0.113458 3.006252e-37   ★
# answer_B answer_D        0.086855 0.007667 11.328361 9.496559e-30  0.071828 0.101882 1.899312e-29   ★
# answer_C answer_D       -0.011576 0.007667 -1.509815 1.310907e-01 -0.026603 0.003451 1.310907e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__A__pairwise.csv
#
# --- HUNTERS, selected = B ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.115893 1.030053 1.201734
# answer_B C(area_label)[answer_B]  1.617770 1.531929 1.703610
# answer_C C(area_label)[answer_C]  0.928491 0.842650 1.014331
# answer_D C(area_label)[answer_D]  0.961203 0.875363 1.047044
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j      se          t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_B answer_C        0.689279 0.03498  19.705175 1.946669e-86  0.620720  0.757838 1.168001e-85   ★
# answer_B answer_D        0.656566 0.03498  18.769979 1.329380e-78  0.588007  0.725125 6.646898e-78   ★
# answer_A answer_B       -0.501876 0.03498 -14.347692 1.101424e-46 -0.570435 -0.433318 4.405694e-46   ★
# answer_A answer_C        0.187403 0.03498   5.357483 8.438908e-08  0.118844  0.255961 2.531672e-07   ★
# answer_A answer_D        0.154690 0.03498   4.422287 9.766151e-06  0.086131  0.223248 1.953230e-05   ★
# answer_C answer_D       -0.032713 0.03498  -0.935196 3.496872e-01 -0.101272  0.035846 3.496872e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__B__pairwise.csv
#
# --- HUNTERS, selected = C ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.250414 1.134237 1.366591
# answer_B C(area_label)[answer_B]  1.201914 1.085737 1.318091
# answer_C C(area_label)[answer_C]  1.688147 1.571970 1.804324
# answer_D C(area_label)[answer_D]  1.055614 0.939437 1.171791
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_C answer_D        0.632533 0.049099 12.882769 5.627967e-38  0.536301  0.728766 3.376780e-37   ★
# answer_B answer_C       -0.486233 0.049099 -9.903082 4.036394e-23 -0.582466 -0.390001 2.018197e-22   ★
# answer_A answer_C       -0.437734 0.049099 -8.915294 4.865220e-19 -0.533966 -0.341501 1.946088e-18   ★
# answer_A answer_D        0.194800 0.049099  3.967474 7.263830e-05  0.098567  0.291032 2.179149e-04   ★
# answer_B answer_D        0.146300 0.049099  2.979687 2.885435e-03  0.050068  0.242533 5.770870e-03   ★
# answer_A answer_B        0.048500 0.049099  0.987788 3.232565e-01 -0.047733  0.144732 3.232565e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__C__pairwise.csv
#
# --- HUNTERS, selected = D ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.336324 1.153676 1.518972
# answer_B C(area_label)[answer_B]  1.231245 1.048597 1.413893
# answer_C C(area_label)[answer_C]  1.162182 0.979533 1.344830
# answer_D C(area_label)[answer_D]  1.815465 1.632816 1.998113
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_C answer_D       -0.653283 0.088274 -7.400627 1.355429e-13 -0.826297 -0.480269 8.132576e-13   ★
# answer_B answer_D       -0.584220 0.088274 -6.618252 3.634722e-11 -0.757233 -0.411206 1.817361e-10   ★
# answer_A answer_D       -0.479141 0.088274 -5.427878 5.702786e-08 -0.652154 -0.306127 2.281114e-07   ★
# answer_A answer_C        0.174142 0.088274  1.972749 4.852421e-02  0.001129  0.347156 1.455726e-01
# answer_B answer_C        0.069063 0.088274  0.782376 4.339939e-01 -0.103950  0.242077 4.677996e-01
# answer_A answer_B        0.105079 0.088274  1.190373 2.338998e-01 -0.067935  0.278093 4.677996e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/hunters/hunters__D__pairwise.csv
#
# === HUNTERS — metric: mean_first_fixation_duration ===
#
# --- HUNTERS, selected = A ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 125.699592 123.020454 128.378731
# answer_B C(area_label)[answer_B]  93.352681  90.673542  96.031820
# answer_C C(area_label)[answer_C]  85.279377  82.600238  87.958516
# answer_D C(area_label)[answer_D]  87.906641  85.227503  90.585780
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_A answer_B       32.346911 0.705951 45.820344 0.000000e+00 30.963273 33.730550 0.000000e+00   ★
# answer_A answer_C       40.420215 0.705951 57.256414 0.000000e+00 39.036577 41.803853 0.000000e+00   ★
# answer_A answer_D       37.792951 0.705951 53.534818 0.000000e+00 36.409313 39.176589 0.000000e+00   ★
# answer_B answer_C        8.073304 0.705951 11.436071 2.761096e-30  6.689666  9.456942 8.283287e-30   ★
# answer_B answer_D        5.446040 0.705951  7.714474 1.214820e-14  4.062401  6.829678 2.429639e-14   ★
# answer_C answer_D       -2.627264 0.705951 -3.721596 1.979672e-04 -4.010902 -1.243626 1.979672e-04   ★
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__A__pairwise.csv
#
# --- HUNTERS, selected = B ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 106.497183 101.786058 111.208308
# answer_B C(area_label)[answer_B] 136.303177 131.592052 141.014303
# answer_C C(area_label)[answer_C]  96.101357  91.390232 100.812483
# answer_D C(area_label)[answer_D]  98.282475  93.571350 102.993600
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc     ci_low    ci_high   p_adj_holm sig
# answer_B answer_C       40.201820 2.496103  16.105836 2.321377e-58  35.309549  45.094091 1.392826e-57   ★
# answer_B answer_D       38.020703 2.496103  15.232027 2.167646e-52  33.128431  42.912974 1.083823e-51   ★
# answer_A answer_B      -29.805995 2.496103 -11.941013 7.233643e-33 -34.698266 -24.913723 2.893457e-32   ★
# answer_A answer_C       10.395825 2.496103   4.164823 3.115942e-05   5.503554  15.288097 9.347827e-05   ★
# answer_A answer_D        8.214708 2.496103   3.291014 9.982701e-04   3.322437  13.106979 1.996540e-03   ★
# answer_C answer_D       -2.181117 2.496103  -0.873809 3.822222e-01  -7.073389   2.711154 3.822222e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__B__pairwise.csv
#
# --- HUNTERS, selected = C ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 113.507462 108.095883 118.919041
# answer_B C(area_label)[answer_B] 110.109327 104.697748 115.520906
# answer_C C(area_label)[answer_C] 132.100357 126.688777 137.511936
# answer_D C(area_label)[answer_D] 105.113490  99.701910 110.525069
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc     ci_low    ci_high   p_adj_holm sig
# answer_C answer_D       26.986867 3.135713  8.606295 7.546003e-18  20.840983  33.132751 4.527602e-17   ★
# answer_B answer_C      -21.991029 3.135713 -7.013088 2.331142e-12 -28.136913 -15.845146 1.165571e-11   ★
# answer_A answer_C      -18.592894 3.135713 -5.929400 3.040435e-09 -24.738778 -12.447011 1.216174e-08   ★
# answer_A answer_D        8.393973 3.135713  2.676895 7.430798e-03   2.248089  14.539856 2.229239e-02   ★
# answer_B answer_D        4.995838 3.135713  1.593206 1.111139e-01  -1.150046  11.141721 2.222278e-01
# answer_A answer_B        3.398135 3.135713  1.083688 2.785030e-01  -2.747749   9.544019 2.785030e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__C__pairwise.csv
#
# --- HUNTERS, selected = D ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 115.605501 107.642091 123.568911
# answer_B C(area_label)[answer_B] 117.072782 109.109373 125.036192
# answer_C C(area_label)[answer_C] 112.233390 104.269981 120.196800
# answer_D C(area_label)[answer_D] 140.835900 132.872491 148.799310
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc     ci_low    ci_high   p_adj_holm sig
# answer_C answer_D      -28.602510 4.903819 -5.832701 5.453738e-09 -38.213819 -18.991201 3.272243e-08   ★
# answer_A answer_D      -25.230399 4.903819 -5.145051 2.674485e-07 -34.841709 -15.619090 1.337243e-06   ★
# answer_B answer_D      -23.763118 4.903819 -4.845839 1.260778e-06 -33.374427 -14.151809 5.043113e-06   ★
# answer_B answer_C        4.839392 4.903819  0.986862 3.237104e-01  -4.771918  14.450701 9.711313e-01
# answer_A answer_B       -1.467281 4.903819 -0.299212 7.647784e-01 -11.078590   8.144028 9.833466e-01
# answer_A answer_C        3.372111 4.903819  0.687650 4.916733e-01  -6.239199  12.983420 9.833466e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_first_fixation_duration/hunters/hunters__D__pairwise.csv
#
# === HUNTERS — metric: skip_rate ===
#
# --- HUNTERS, selected = A ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.349704 0.337562 0.361847
# answer_B C(area_label)[answer_B]  0.485775 0.473632 0.497917
# answer_C C(area_label)[answer_C]  0.524152 0.512009 0.536294
# answer_D C(area_label)[answer_D]  0.510923 0.498781 0.523066
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_A answer_B       -0.136070 0.002861 -47.555442 0.000000e+00 -0.141678 -0.130462 0.000000e+00   ★
# answer_A answer_C       -0.174447 0.002861 -60.967887 0.000000e+00 -0.180055 -0.168839 0.000000e+00   ★
# answer_A answer_D       -0.161219 0.002861 -56.344640 0.000000e+00 -0.166827 -0.155611 0.000000e+00   ★
# answer_B answer_C       -0.038377 0.002861 -13.412446 5.112473e-41 -0.043985 -0.032769 1.533742e-40   ★
# answer_B answer_D       -0.025149 0.002861  -8.789199 1.506306e-18 -0.030757 -0.019540 3.012612e-18   ★
# answer_C answer_D        0.013228 0.002861   4.623247 3.777795e-06  0.007620  0.018837 3.777795e-06   ★
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__A__pairwise.csv
#
# --- HUNTERS, selected = B ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.427742 0.407928 0.447556
# answer_B C(area_label)[answer_B]  0.302420 0.282607 0.322234
# answer_C C(area_label)[answer_C]  0.471299 0.451485 0.491113
# answer_D C(area_label)[answer_D]  0.456646 0.436832 0.476459
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_B answer_C       -0.168879 0.009709 -17.393143 9.299223e-68 -0.187909 -0.149848 5.579534e-67   ★
# answer_B answer_D       -0.154225 0.009709 -15.883982 8.181555e-57 -0.173256 -0.135195 4.090777e-56   ★
# answer_A answer_B        0.125322 0.009709  12.907110 4.104168e-38  0.106291  0.144352 1.641667e-37   ★
# answer_A answer_C       -0.043557 0.009709  -4.486033 7.256159e-06 -0.062587 -0.024527 2.176848e-05   ★
# answer_A answer_D       -0.028904 0.009709  -2.976872 2.912058e-03 -0.047934 -0.009874 5.824115e-03   ★
# answer_C answer_D        0.014653 0.009709   1.509161 1.312577e-01 -0.004377  0.033683 1.312577e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__B__pairwise.csv
#
# --- HUNTERS, selected = C ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.387873 0.363512 0.412235
# answer_B C(area_label)[answer_B]  0.406730 0.382368 0.431091
# answer_C C(area_label)[answer_C]  0.301946 0.277585 0.326308
# answer_D C(area_label)[answer_D]  0.425660 0.401299 0.450022
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_C answer_D       -0.123714 0.013301 -9.301008 1.391199e-20 -0.149784 -0.097644 8.347192e-20   ★
# answer_B answer_C        0.104784 0.013301  7.877798 3.332019e-15  0.078714  0.130853 1.666010e-14   ★
# answer_A answer_C        0.085927 0.013301  6.460124 1.046172e-10  0.059857  0.111997 4.184689e-10   ★
# answer_A answer_D       -0.037787 0.013301 -2.840884 4.498861e-03 -0.063857 -0.011717 1.349658e-02   ★
# answer_A answer_B       -0.018857 0.013301 -1.417674 1.562861e-01 -0.044926  0.007213 3.093501e-01
# answer_B answer_D       -0.018930 0.013301 -1.423211 1.546750e-01 -0.045000  0.007139 3.093501e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__C__pairwise.csv
#
# --- HUNTERS, selected = D ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.380803 0.345769 0.415838
# answer_B C(area_label)[answer_B]  0.364352 0.329317 0.399386
# answer_C C(area_label)[answer_C]  0.390739 0.355705 0.425773
# answer_D C(area_label)[answer_D]  0.272250 0.237216 0.307284
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low  ci_high   p_adj_holm sig
# answer_C answer_D        0.118489 0.020295  5.838442 5.269115e-09  0.078712 0.158266 3.161469e-08   ★
# answer_A answer_D        0.108553 0.020295  5.348871 8.850448e-08  0.068777 0.148330 4.425224e-07   ★
# answer_B answer_D        0.092101 0.020295  4.538215 5.673252e-06  0.052325 0.131878 2.269301e-05   ★
# answer_B answer_C       -0.026388 0.020295 -1.300228 1.935230e-01 -0.066164 0.013389 5.805689e-01
# answer_A answer_B        0.016452 0.020295  0.810657 4.175629e-01 -0.023325 0.056229 8.351257e-01
# answer_A answer_C       -0.009936 0.020295 -0.489571 6.244375e-01 -0.049712 0.029841 8.351257e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/hunters/hunters__D__pairwise.csv
#
# === HUNTERS — metric: area_dwell_proportion ===
#
# --- HUNTERS, selected = A ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.350668 0.348196 0.353139
# answer_B C(area_label)[answer_B]  0.220340 0.217869 0.222812
# answer_C C(area_label)[answer_C]  0.199041 0.196570 0.201513
# answer_D C(area_label)[answer_D]  0.182183 0.179711 0.184655
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t         p_unc   ci_low  ci_high    p_adj_holm sig
# answer_A answer_B        0.130327 0.001752 74.383589  0.000000e+00 0.126893 0.133761  0.000000e+00   ★
# answer_A answer_C        0.151626 0.001752 86.539942  0.000000e+00 0.148192 0.155060  0.000000e+00   ★
# answer_A answer_D        0.168485 0.001752 96.161869  0.000000e+00 0.165051 0.171919  0.000000e+00   ★
# answer_B answer_D        0.038158 0.001752 21.778280 3.728061e-105 0.034724 0.041592 1.118418e-104   ★
# answer_B answer_C        0.021299 0.001752 12.156354  5.307538e-34 0.017865 0.024733  1.061508e-33   ★
# answer_C answer_D        0.016859 0.001752  9.621927  6.460945e-22 0.013424 0.020293  6.460945e-22   ★
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__A__pairwise.csv
#
# --- HUNTERS, selected = B ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 672.592297
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.220639 0.211717 0.229562
# answer_B C(area_label)[answer_B]  0.353797 0.344875 0.362720
# answer_C C(area_label)[answer_C]  0.201657 0.192735 0.210580
# answer_D C(area_label)[answer_D]  0.173755 0.164832 0.182677
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t         p_unc    ci_low   ci_high    p_adj_holm sig
# answer_B answer_D        0.180043 0.005817  30.952956 2.318303e-210  0.168642  0.191443 1.390982e-209   ★
# answer_B answer_C        0.152140 0.005817  26.155908 8.442415e-151  0.140740  0.163541 4.221207e-150   ★
# answer_A answer_B       -0.133158 0.005817 -22.892528 5.514928e-116 -0.144559 -0.121758 2.205971e-115   ★
# answer_A answer_D        0.046885 0.005817   8.060428  7.602775e-16  0.035484  0.058285  2.280833e-15   ★
# answer_C answer_D        0.027903 0.005817   4.797048  1.610211e-06  0.016502  0.039303  3.220423e-06   ★
# answer_A answer_C        0.018982 0.005817   3.263380  1.100917e-03  0.007582  0.030382  1.100917e-03   ★
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__B__pairwise.csv
#
# --- HUNTERS, selected = C ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 266.366845
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.208802 0.196446 0.221159
# answer_B C(area_label)[answer_B]  0.213084 0.200728 0.225441
# answer_C C(area_label)[answer_C]  0.350208 0.337851 0.362564
# answer_D C(area_label)[answer_D]  0.168349 0.155992 0.180705
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t         p_unc    ci_low   ci_high    p_adj_holm sig
# answer_C answer_D        0.181859 0.007616  23.879071 5.053913e-126  0.166932  0.196786 3.032348e-125   ★
# answer_A answer_C       -0.141405 0.007616 -18.567287  5.911557e-77 -0.156332 -0.126479  2.955778e-76   ★
# answer_B answer_C       -0.137123 0.007616 -18.005045  1.778554e-72 -0.152050 -0.122197  7.114215e-72   ★
# answer_B answer_D        0.044736 0.007616   5.874026  4.253361e-09  0.029809  0.059662  1.276008e-08   ★
# answer_A answer_D        0.040454 0.007616   5.311784  1.085571e-07  0.025527  0.055380  2.171141e-07   ★
# answer_A answer_B       -0.004282 0.007616  -0.562242  5.739512e-01 -0.019209  0.010645  5.739512e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__C__pairwise.csv
#
# --- HUNTERS, selected = D ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 126.328883
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.213512 0.196324 0.230699
# answer_B C(area_label)[answer_B]  0.219217 0.202030 0.236405
# answer_C C(area_label)[answer_C]  0.211707 0.194520 0.228895
# answer_D C(area_label)[answer_D]  0.297918 0.280730 0.315105
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_C answer_D       -0.086210 0.011363 -7.587015 3.273583e-14 -0.108481 -0.063940 1.964150e-13   ★
# answer_A answer_D       -0.084406 0.011363 -7.428199 1.100862e-13 -0.106677 -0.062135 5.504311e-13   ★
# answer_B answer_D       -0.078701 0.011363 -6.926117 4.325499e-12 -0.100972 -0.056430 1.730199e-11   ★
# answer_A answer_B       -0.005705 0.011363 -0.502082 6.156096e-01 -0.027976  0.016566 1.000000e+00
# answer_B answer_C        0.007510 0.011363  0.660899 5.086773e-01 -0.014761  0.029781 1.000000e+00
# answer_A answer_C        0.001805 0.011363  0.158816 8.738136e-01 -0.020466  0.024075 1.000000e+00
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/hunters/hunters__D__pairwise.csv
#
# === GATHERERS — metric: mean_dwell_time ===
#
# --- GATHERERS, selected = A ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 253.272860 245.302464 261.243255
# answer_B C(area_label)[answer_B] 163.954079 155.983684 171.924474
# answer_C C(area_label)[answer_C] 142.102564 134.132169 150.072959
# answer_D C(area_label)[answer_D] 141.959141 133.988746 149.929537
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc     ci_low    ci_high   p_adj_holm sig
# answer_A answer_B       89.318780 1.994535 44.781767 0.000000e+00  85.409564  93.227996 0.000000e+00   ★
# answer_A answer_C      111.170296 1.994535 55.737464 0.000000e+00 107.261080 115.079511 0.000000e+00   ★
# answer_A answer_D      111.313718 1.994535 55.809371 0.000000e+00 107.404502 115.222934 0.000000e+00   ★
# answer_B answer_D       21.994938 1.994535 11.027604 2.812571e-28  18.085722  25.904154 8.437712e-28   ★
# answer_B answer_C       21.851515 1.994535 10.955697 6.239635e-28  17.942300  25.760731 1.247927e-27   ★
# answer_C answer_D        0.143422 1.994535  0.071908 9.426753e-01  -3.765793   4.052638 9.426753e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__A__pairwise.csv
#
# --- GATHERERS, selected = B ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 239.166504 221.093203 257.239805
# answer_B C(area_label)[answer_B] 358.629860 340.556559 376.703161
# answer_C C(area_label)[answer_C] 183.021367 164.948066 201.094668
# answer_D C(area_label)[answer_D] 177.116450 159.043149 195.189751
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc      ci_low     ci_high   p_adj_holm sig
# answer_B answer_D      181.513410 9.302774  19.511750 8.724311e-85  163.280308  199.746513 5.234587e-84   ★
# answer_B answer_C      175.608494 9.302774  18.877002 1.763128e-79  157.375391  193.841596 8.815638e-79   ★
# answer_A answer_B     -119.463356 9.302774 -12.841691 9.575931e-38 -137.696459 -101.230253 3.830372e-37   ★
# answer_A answer_D       62.050054 9.302774   6.670059 2.557005e-11   43.816952   80.283157 7.671014e-11   ★
# answer_A answer_C       56.145137 9.302774   6.035311 1.586567e-09   37.912035   74.378240 3.173134e-09   ★
# answer_C answer_D        5.904917 9.302774   0.634748 5.255928e-01  -12.328186   24.138020 5.255928e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__B__pairwise.csv
#
# --- GATHERERS, selected = C ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 239.317085 215.440485 263.193684
# answer_B C(area_label)[answer_B] 233.611491 209.734891 257.488091
# answer_C C(area_label)[answer_C] 358.242134 334.365534 382.118733
# answer_D C(area_label)[answer_D] 209.940488 186.063888 233.817087
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc      ci_low     ci_high   p_adj_holm sig
# answer_C answer_D      148.301646 10.79253  13.741139 5.756337e-43  127.148677  169.454616 3.453802e-42   ★
# answer_B answer_C     -124.630643 10.79253 -11.547862 7.567977e-31 -145.783612 -103.477673 3.783988e-30   ★
# answer_A answer_C     -118.925049 10.79253 -11.019201 3.087894e-28 -140.078018  -97.772079 1.235158e-27   ★
# answer_A answer_D       29.376597 10.79253   2.721938 6.490031e-03    8.223628   50.529567 1.947009e-02   ★
# answer_B answer_D       23.671004 10.79253   2.193277 2.828745e-02    2.518034   44.823973 5.657490e-02
# answer_A answer_B        5.705594 10.79253   0.528661 5.970404e-01  -15.447376   26.858563 5.970404e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__C__pairwise.csv
#
# --- GATHERERS, selected = D ---
#
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 291.738007 256.348244 327.127770
# answer_B C(area_label)[answer_B] 236.163710 200.773947 271.553474
# answer_C C(area_label)[answer_C] 249.733608 214.343845 285.123371
# answer_D C(area_label)[answer_D] 384.225095 348.835332 419.614858
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j        se         t        p_unc      ci_low     ci_high   p_adj_holm sig
# answer_B answer_D     -148.061384 17.066875 -8.675366 4.122240e-18 -181.511846 -114.610923 2.473344e-17   ★
# answer_C answer_D     -134.491487 17.066875 -7.880264 3.266897e-15 -167.941948 -101.041026 1.633448e-14   ★
# answer_A answer_D      -92.487088 17.066875 -5.419099 5.990015e-08 -125.937549  -59.036626 2.396006e-07   ★
# answer_A answer_B       55.574297 17.066875  3.256267 1.128877e-03   22.123836   89.024758 3.386631e-03   ★
# answer_A answer_C       42.004399 17.066875  2.461165 1.384866e-02    8.553938   75.454861 2.769732e-02   ★
# answer_B answer_C      -13.569897 17.066875 -0.795101 4.265545e-01  -47.020359   19.880564 4.265545e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_dwell_time/gatherers/gatherers__D__pairwise.csv
#
# === GATHERERS — metric: mean_fixations_count ===
#
# --- GATHERERS, selected = A ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.263417 1.227594 1.299239
# answer_B C(area_label)[answer_B]  0.869646 0.833824 0.905469
# answer_C C(area_label)[answer_C]  0.765327 0.729505 0.801150
# answer_D C(area_label)[answer_D]  0.770642 0.734820 0.806464
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low  ci_high   p_adj_holm sig
# answer_A answer_B        0.393770 0.008212 47.948252 0.000000e+00  0.377674 0.409866 0.000000e+00   ★
# answer_A answer_C        0.498089 0.008212 60.650863 0.000000e+00  0.481993 0.514185 0.000000e+00   ★
# answer_A answer_D        0.492775 0.008212 60.003695 0.000000e+00  0.476679 0.508871 0.000000e+00   ★
# answer_B answer_C        0.104319 0.008212 12.702610 5.718969e-37  0.088223 0.120415 1.715691e-36   ★
# answer_B answer_D        0.099004 0.008212 12.055443 1.815542e-33  0.082908 0.115100 3.631083e-33   ★
# answer_C answer_D       -0.005315 0.008212 -0.647168 5.175234e-01 -0.021411 0.010781 5.175234e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__A__pairwise.csv
#
# --- GATHERERS, selected = B ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.198077 1.124695 1.271459
# answer_B C(area_label)[answer_B]  1.685201 1.611819 1.758584
# answer_C C(area_label)[answer_C]  0.953287 0.879905 1.026669
# answer_D C(area_label)[answer_D]  0.933475 0.860092 1.006857
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t         p_unc    ci_low   ci_high    p_adj_holm sig
# answer_B answer_D        0.751727 0.034895  21.542502 6.225224e-103  0.683334  0.820120 3.735135e-102   ★
# answer_B answer_C        0.731915 0.034895  20.974732  1.115940e-97  0.663521  0.800308  5.579698e-97   ★
# answer_A answer_B       -0.487125 0.034895 -13.959702  2.745802e-44 -0.555518 -0.418732  1.098321e-43   ★
# answer_A answer_D        0.264602 0.034895   7.582800  3.381760e-14  0.196209  0.332995  1.014528e-13   ★
# answer_A answer_C        0.244790 0.034895   7.015030  2.298997e-12  0.176397  0.313183  4.597993e-12   ★
# answer_C answer_D        0.019812 0.034895   0.567770  5.701911e-01 -0.048581  0.088205  5.701911e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__B__pairwise.csv
#
# --- GATHERERS, selected = C ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.199028 1.106959 1.291097
# answer_B C(area_label)[answer_B]  1.195024 1.102955 1.287093
# answer_C C(area_label)[answer_C]  1.708436 1.616367 1.800505
# answer_D C(area_label)[answer_D]  1.082829 0.990760 1.174898
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_C answer_D        0.625606 0.040871  15.306796 6.887443e-53  0.545500  0.705712 4.132466e-52   ★
# answer_B answer_C       -0.513412 0.040871 -12.561716 3.428182e-36 -0.593518 -0.433306 1.714091e-35   ★
# answer_A answer_C       -0.509408 0.040871 -12.463756 1.176942e-35 -0.589514 -0.429302 4.707769e-35   ★
# answer_A answer_D        0.116198 0.040871   2.843040 4.468548e-03  0.036092  0.196304 1.340564e-02   ★
# answer_B answer_D        0.112195 0.040871   2.745080 6.049610e-03  0.032089  0.192301 1.340564e-02   ★
# answer_A answer_B        0.004004 0.040871   0.097960 9.219643e-01 -0.076102  0.084110 9.219643e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__C__pairwise.csv
#
# --- GATHERERS, selected = D ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  1.408699 1.262128 1.555269
# answer_B C(area_label)[answer_B]  1.209123 1.062553 1.355693
# answer_C C(area_label)[answer_C]  1.242793 1.096223 1.389363
# answer_D C(area_label)[answer_D]  1.811240 1.664670 1.957811
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_B answer_D       -0.602117 0.068347 -8.809773 1.254000e-18 -0.736074 -0.468161 7.524001e-18   ★
# answer_C answer_D       -0.568447 0.068347 -8.317136 9.011458e-17 -0.702404 -0.434491 4.505729e-16   ★
# answer_A answer_D       -0.402542 0.068347 -5.889718 3.868548e-09 -0.536498 -0.268585 1.547419e-08   ★
# answer_A answer_B        0.199576 0.068347  2.920054 3.499703e-03  0.065619  0.333532 1.049911e-02   ★
# answer_A answer_C        0.165906 0.068347  2.427418 1.520674e-02  0.031949  0.299862 3.041349e-02   ★
# answer_B answer_C       -0.033670 0.068347 -0.492637 6.222692e-01 -0.167627  0.100287 6.222692e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_fixations_count/gatherers/gatherers__D__pairwise.csv
#
# === GATHERERS — metric: mean_first_fixation_duration ===
#
# --- GATHERERS, selected = A ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 126.287617 114.370479 138.204756
# answer_B C(area_label)[answer_B]  99.648049  87.730911 111.565188
# answer_C C(area_label)[answer_C]  92.070976  80.153837 103.988114
# answer_D C(area_label)[answer_D]  93.796635  81.879496 105.713773
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t         p_unc    ci_low   ci_high    p_adj_holm sig
# answer_A answer_C       34.216642 0.719203 47.575795  0.000000e+00 32.807030 35.626253  0.000000e+00   ★
# answer_A answer_D       32.490983 0.719203 45.176390  0.000000e+00 31.081371 33.900594  0.000000e+00   ★
# answer_A answer_B       26.639568 0.719203 37.040416 2.562034e-300 25.229956 28.049179 1.024813e-299   ★
# answer_B answer_C        7.577074 0.719203 10.535380  5.934340e-26  6.167462  8.986685  1.780302e-25   ★
# answer_B answer_D        5.851415 0.719203  8.135974  4.086392e-16  4.441803  7.261026  8.172784e-16   ★
# answer_C answer_D       -1.725659 0.719203 -2.399405  1.642172e-02 -3.135270 -0.316048  1.642172e-02   ★
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_first_fixation_duration/gatherers/gatherers__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_first_fixation_duration/gatherers/gatherers__A__pairwise.csv
#
# --- GATHERERS, selected = B ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 38.461814
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term   estimate     ci_low    ci_high
# answer_A C(area_label)[answer_A] 110.958830 105.922122 115.995538
# answer_B C(area_label)[answer_B] 139.978720 134.942012 145.015429
# answer_C C(area_label)[answer_C] 102.498510  97.461802 107.535218
# answer_D C(area_label)[answer_D] 102.153597  97.116888 107.190305
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc     ci_low    ci_high   p_adj_holm sig
# answer_B answer_D       37.825124 2.161374  17.500500 1.420171e-68  33.588909  42.061339 8.521028e-68   ★
# answer_B answer_C       37.480210 2.161374  17.340919 2.310123e-67  33.243995  41.716425 1.155061e-66   ★
# answer_A answer_B      -29.019890 2.161374 -13.426594 4.223958e-41 -33.256105 -24.783675 1.689583e-40   ★
# answer_A answer_D        8.805234 2.161374   4.073906 4.623119e-05   4.569019  13.041449 1.386936e-04   ★
# answer_A answer_C        8.460320 2.161374   3.914325 9.065739e-05   4.224105  12.696535 1.813148e-04   ★
# answer_C answer_D        0.344913 2.161374   0.159581 8.732115e-01  -3.891302   4.581128 8.732115e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/mean_first_fixation_duration/gatherers/gatherers__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/mean_first_fixation_duration/gatherers/gatherers__B__pairwise.csv
#
# ...
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.344002 0.330873 0.357131
# answer_B C(area_label)[answer_B]  0.459255 0.446126 0.472384
# answer_C C(area_label)[answer_C]  0.494498 0.481369 0.507626
# answer_D C(area_label)[answer_D]  0.481073 0.467944 0.494202
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_A answer_B       -0.115253 0.002901 -39.724101 0.000000e+00 -0.120940 -0.109567 0.000000e+00   ★
# answer_A answer_C       -0.150496 0.002901 -51.871133 0.000000e+00 -0.156182 -0.144809 0.000000e+00   ★
# answer_A answer_D       -0.137071 0.002901 -47.244040 0.000000e+00 -0.142758 -0.131384 0.000000e+00   ★
# answer_B answer_C       -0.035243 0.002901 -12.147033 5.948568e-34 -0.040929 -0.029556 1.784571e-33   ★
# answer_B answer_D       -0.021818 0.002901  -7.519939 5.480166e-14 -0.027504 -0.016131 1.096033e-13   ★
# answer_C answer_D        0.013425 0.002901   4.627093 3.708336e-06  0.007738  0.019111 3.708336e-06   ★
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__A__pairwise.csv
#
# --- GATHERERS, selected = B ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.407832 0.389127 0.426537
# answer_B C(area_label)[answer_B]  0.294670 0.275965 0.313375
# answer_C C(area_label)[answer_C]  0.443192 0.424486 0.461897
# answer_D C(area_label)[answer_D]  0.446214 0.427509 0.464919
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_B answer_D       -0.151544 0.008269 -18.326605 5.076160e-75 -0.167751 -0.135337 3.045696e-74   ★
# answer_B answer_C       -0.148521 0.008269 -17.961106 3.929040e-72 -0.164729 -0.132314 1.964520e-71   ★
# answer_A answer_B        0.113162 0.008269  13.684960 1.248751e-42  0.096955  0.129369 4.995006e-42   ★
# answer_A answer_D       -0.038382 0.008269  -4.641645 3.456470e-06 -0.054589 -0.022175 1.036941e-05   ★
# answer_A answer_C       -0.035360 0.008269  -4.276145 1.901573e-05 -0.051567 -0.019153 3.803146e-05   ★
# answer_C answer_D       -0.003022 0.008269  -0.365500 7.147386e-01 -0.019229  0.013185 7.147386e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__B__pairwise.csv
#
# --- GATHERERS, selected = C ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.384012 0.362081 0.405943
# answer_B C(area_label)[answer_B]  0.393943 0.372011 0.415874
# answer_C C(area_label)[answer_C]  0.286532 0.264601 0.308464
# answer_D C(area_label)[answer_D]  0.399785 0.377854 0.421716
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_C answer_D       -0.113253 0.010398 -10.891464 1.265889e-27 -0.133633 -0.092872 7.595335e-27   ★
# answer_B answer_C        0.107410 0.010398  10.329593 5.177989e-25  0.087030  0.127790 2.588995e-24   ★
# answer_A answer_C        0.097479 0.010398   9.374548 6.947280e-21  0.077099  0.117860 2.778912e-20   ★
# answer_A answer_D       -0.015773 0.010398  -1.516916 1.292879e-01 -0.036154  0.004607 3.878638e-01
# answer_A answer_B       -0.009931 0.010398  -0.955045 3.395550e-01 -0.030311  0.010449 6.791100e-01
# answer_B answer_D       -0.005842 0.010398  -0.561871 5.742039e-01 -0.026223  0.014538 6.791100e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__C__pairwise.csv
#
# --- GATHERERS, selected = D ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.365142 0.335178 0.395105
# answer_B C(area_label)[answer_B]  0.369536 0.339572 0.399499
# answer_C C(area_label)[answer_C]  0.381521 0.351558 0.411484
# answer_D C(area_label)[answer_D]  0.279408 0.249445 0.309371
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se         t        p_unc    ci_low  ci_high   p_adj_holm sig
# answer_C answer_D        0.102113 0.014703  6.945014 3.784232e-12  0.073296 0.130930 2.270539e-11   ★
# answer_B answer_D        0.090128 0.014703  6.129865 8.795381e-10  0.061310 0.118945 4.397690e-09   ★
# answer_A answer_D        0.085734 0.014703  5.831006 5.509423e-09  0.056916 0.114551 2.203769e-08   ★
# answer_A answer_C       -0.016379 0.014703 -1.114008 2.652758e-01 -0.045197 0.012438 7.958274e-01
# answer_B answer_C       -0.011985 0.014703 -0.815149 4.149870e-01 -0.040803 0.016832 8.299740e-01
# answer_A answer_B       -0.004394 0.014703 -0.298859 7.650478e-01 -0.033212 0.024423 8.299740e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/skip_rate/gatherers/gatherers__D__pairwise.csv
#
# === GATHERERS — metric: area_dwell_proportion ===
#
# --- GATHERERS, selected = A ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.336552 0.334060 0.339044
# answer_B C(area_label)[answer_B]  0.225651 0.223159 0.228143
# answer_C C(area_label)[answer_C]  0.204967 0.202475 0.207460
# answer_D C(area_label)[answer_D]  0.183043 0.180550 0.185535
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j      se         t         p_unc   ci_low  ci_high    p_adj_holm sig
# answer_A answer_B        0.110901 0.00177 62.648633  0.000000e+00 0.107431 0.114371  0.000000e+00   ★
# answer_A answer_C        0.131584 0.00177 74.332837  0.000000e+00 0.128115 0.135054  0.000000e+00   ★
# answer_A answer_D        0.153509 0.00177 86.718297  0.000000e+00 0.150040 0.156979  0.000000e+00   ★
# answer_B answer_D        0.042608 0.00177 24.069664 5.196918e-128 0.039139 0.046078 1.559075e-127   ★
# answer_C answer_D        0.021925 0.00177 12.385460  3.132840e-35 0.018455 0.025394  6.265681e-35   ★
# answer_B answer_C        0.020683 0.00177 11.684204  1.535106e-31 0.017214 0.024153  1.535106e-31   ★
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__A__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__A__pairwise.csv
#
# --- GATHERERS, selected = B ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 710.872757
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.209853 0.201544 0.218162
# answer_B C(area_label)[answer_B]  0.347088 0.338779 0.355397
# answer_C C(area_label)[answer_C]  0.206374 0.198065 0.214683
# answer_D C(area_label)[answer_D]  0.171624 0.163315 0.179933
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t         p_unc    ci_low   ci_high    p_adj_holm sig
# answer_B answer_D        0.175464 0.004982  35.222981 8.896400e-272  0.165700  0.185228 5.337840e-271   ★
# answer_B answer_C        0.140714 0.004982  28.247102 1.544907e-175  0.130950  0.150477 7.724534e-175   ★
# answer_A answer_B       -0.137235 0.004982 -27.548722 4.584179e-167 -0.146998 -0.127471 1.833672e-166   ★
# answer_A answer_D        0.038229 0.004982   7.674259  1.663771e-14  0.028466  0.047993  4.991314e-14   ★
# answer_C answer_D        0.034750 0.004982   6.975879  3.039645e-12  0.024987  0.044514  6.079290e-12   ★
# answer_A answer_C        0.003479 0.004982   0.698380  4.849393e-01 -0.006285  0.013243  4.849393e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__B__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__B__pairwise.csv
#
# --- GATHERERS, selected = C ---
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 399.913535
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.201573 0.192080 0.211065
# answer_B C(area_label)[answer_B]  0.202536 0.193043 0.212028
# answer_C C(area_label)[answer_C]  0.338059 0.328567 0.347552
# answer_D C(area_label)[answer_D]  0.181996 0.172503 0.191489
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j       se          t         p_unc    ci_low   ci_high    p_adj_holm sig
# answer_C answer_D        0.156063 0.005972  26.134550 1.476839e-150  0.144359  0.167767 8.861031e-150   ★
# answer_A answer_C       -0.136487 0.005972 -22.856212 1.267641e-115 -0.148191 -0.124783 6.338205e-115   ★
# answer_B answer_C       -0.135524 0.005972 -22.694935 5.026877e-114 -0.147228 -0.123820 2.010751e-113   ★
# answer_B answer_D        0.020540 0.005972   3.439615  5.825421e-04  0.008836  0.032244  1.747626e-03   ★
# answer_A answer_D        0.019577 0.005972   3.278338  1.044202e-03  0.007873  0.031281  2.088404e-03   ★
# answer_A answer_B       -0.000963 0.005972  -0.161277  8.718754e-01 -0.012667  0.010741  8.718754e-01
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__C__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__C__pairwise.csv
#
# --- GATHERERS, selected = D ---
#
# Fixed effects (per area):
#     area                    term  estimate   ci_low  ci_high
# answer_A C(area_label)[answer_A]  0.216036 0.202176 0.229896
# answer_B C(area_label)[answer_B]  0.206383 0.192523 0.220243
# answer_C C(area_label)[answer_C]  0.212278 0.198418 0.226138
# answer_D C(area_label)[answer_D]  0.288606 0.274745 0.302466
#
# Pairwise comparisons (Holm-corrected):
#   area_i   area_j  diff_i_minus_j      se         t        p_unc    ci_low   ci_high   p_adj_holm sig
# answer_B answer_D       -0.082222 0.00922 -8.917828 4.755225e-19 -0.100293 -0.064151 2.853135e-18   ★
# answer_C answer_D       -0.076328 0.00922 -8.278503 1.247338e-16 -0.094399 -0.058257 6.236692e-16   ★
# answer_A answer_D       -0.072569 0.00922 -7.870877 3.521637e-15 -0.090640 -0.054499 1.408655e-14   ★
# answer_A answer_B        0.009653 0.00922  1.046951 2.951222e-01 -0.008418  0.027724 8.853666e-01
# answer_B answer_C       -0.005895 0.00922 -0.639325 5.226113e-01 -0.023965  0.012176 1.000000e+00
# answer_A answer_C        0.003758 0.00922  0.407626 6.835486e-01 -0.014313  0.021829 1.000000e+00
#
# Saved fixed-effects to:  ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__D__fe.csv
# Saved pairwise table to: ../reports/report_data/area_mixed_models/area_dwell_proportion/gatherers/gatherers__D__pairwise.csv
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 198.414762
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\deeth\miniconda3\envs\QA_eyetracking_env\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
