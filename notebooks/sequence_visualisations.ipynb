# %%
import pandas as pd

from src.viz import sequence_visualisations as SV

from importlib import reload
reload(SV)
# Out:
# <module 'src.viz.sequence_visualisations' from 'C:\\Users\\deeth\\PycharmProjects\\QA_eyetracking\\src\\viz\\sequence_visualisations.py'>

# %%
hunters = pd.read_csv("../data/hunters.csv")
gatherers = pd.read_csv("../data/gatherers.csv")

# %%
data_rows_h = SV.build_sequence_rows(
    hunters,
    representation="raw",  # 'raw' or 'simplified'
    include_question=True
)

data_rows_g = SV.build_sequence_rows(
    gatherers,
    representation="raw",  # 'raw' or 'simplified'
    include_question=True
)

# %%
SV.visualize_by_id(
    data_rows_h,
    by_person_or_text="person", # 'person' or 'text'
    fix_by="label",               # 'label' or 'loc'
    identifier='l11_525'        # or None for random
)
